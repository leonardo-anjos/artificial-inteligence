# %% [markdown]
# # POC PUCOMEX - Atendimento Serpro

# %% [markdown]
# ## Instalação de pacotes necessários

# %%
# Importações básicas - Descomentar as linhas abaixo:
#!pip install pandas
#!pip install tensorflow
#!pip install keras
#!pip install scikit-learn
#!pip install nltk
#!pip install ezodf
#!pip install lxml
#import nltk
#nltk.download('all')
#!pip install spacy
#!python -m spacy download pt_core_news_sm

# %% [markdown]
# ## Importações e criação de funções

# %%
import ezodf
import pandas as pd
import sys
import unicodedata
import re
import time
import spacy
from unicodedata import normalize
from nltk import tokenize # Tokenização
from nltk.corpus import stopwords # Stopwords
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem import RSLPStemmer
# Função para mostrar as planilhas do documento
def show_ods_sheets(filename):
    doc = ezodf.opendoc(filename)
    print("Spreadsheet contains %d sheet(s)." % len(doc.sheets))
    for sheet in doc.sheets:
        print("-"*40)
        print("   Sheet name : '%s'" % sheet.name)
        print("Size of Sheet : (rows=%d, cols=%d)" % (sheet.nrows(), sheet.ncols()) )
# Função para converter ODS em DataFrame do Pandas
def read_sheet_ods_as_panda_dataframe(filename, sheet_no=0, header=0):
    tab = ezodf.opendoc(filename=filename).sheets[sheet_no]
    return pd.DataFrame({col[header].value:[x.value for x in col[header+1:]]
                         for col in tab.columns()})

# %% [markdown]
# ## Abrindo o arquivo como um DataFrame

# %%
# Exibindo informações sobre o arquivo ODS
FILENAME = '/home/03662232677/workspace-neon/PUCOMEX/SS_PUCOMEX_Jan_2018 a Fev_2019_V2.ods'
show_ods_sheets(FILENAME)
# Out:
# Spreadsheet contains 2 sheet(s).
# ----------------------------------------
#    Sheet name : 'SS'
# Size of Sheet : (rows=18172, cols=17)
# ----------------------------------------
#    Sheet name : 'Solution'
# Size of Sheet : (rows=158, cols=11)

# %%
# Lendo o arquivo ODS com o Pandas
df = read_sheet_ods_as_panda_dataframe(FILENAME)

# %% [markdown]
# ## Inspecionando e trabalhando o DataFrame

# %%
# Mostrando os primeiros registros
df.head()
# Out:
#             ticketid     ownergroup        owner  \
# 0  2017SS/0000940433  UNACDFPUCOMEX  72503360106
# 1  2017SS/0000973776  UNACDFPUCOMEX  72503360106
# 2  2017SS/0000986377  CAGSBRPUCOMEX  20656866772
# 3  2017SS/0001008950  UNACDFPUCOMEX  72503360106
# 4  2017SS/0001017121  UNACDFPUCOMEX  72503360106
#
#                                          description        statusdate  \
# 0  CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...  13/03/2018 12:16
# 1  CENTRAL DE SERVIÇOS RFB,CCT - CONTROLE DE CARG...  18/01/2018 23:18
# 2  CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...  04/01/2018 08:13
# 3  CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...  10/01/2018 09:28
# 4  CENTRAL DE SERVIÇOS RFB,CCT - CONTROLE DE CARG...  10/01/2018 09:31
#
#   externalsystem serpronivelaten  \
# 0          EMAIL          3NIVEL
# 1       INTERNET          3NIVEL
# 2          EMAIL          2NIVEL
# 3          EMAIL          3NIVEL
# 4       INTERNET          3NIVEL
#
#                                     descricaodemanda            solution  \
# 0  Bom Dia Tenho dois processos o qual ja voo , n...
# 1  Bom dia, Enviei uma nota para o Siscomex e seu...    2016SOL/00396862
# 2                                                       2016SOL/00399811
# 3  Srs., Fizemos várias tentativas para obter inf...    2017SOL/00003655
# 4  Nro da Solicitação: 2017SS/0001012491: Como so...  2017SOL/0000002832
#
#             description2 UG_Atendimento UG_Serviço relatedreckey  \
# 0       REGRA DE NEGÓCIO          SUNAC      SUNMF
# 1            ANÁLISE URC          SUNAC      SUNMF
# 2  SITUAÇÃO NÃO PREVISTA          SUPCD      SUNMF
# 3       REGRA DE NEGÓCIO          SUNAC      SUNMF
# 4            ANÁLISE URC          SUNAC      SUNMF
#
#   internalpriority                              SS_solucaoparausuario  \
# 0                9  Prezado Usuário\n\nAs cargas estão com a Améri...
# 1                9  \n\nPrezado(a) usuário(a),\nProblema resolvido...
# 2                9  Prezado usuario,segue a informação do nosso de...
# 3                9  Prezado Usuário,\n\nVocê pode estar tirando as...
# 4                9  Caro usuário,\n\nA DUE 17BR0000079935 já se en...
#
#                            Script_solucaoparausuario   NaN
# 0                                            #N/DISP  None
# 1   Sr.(a) usuário(a), conforme contato telefônic...  None
# 2  Sr.(a) usuário(a),conforme informado através d...  None
# 3   \nSr(a). usuário(a),Sua solicitação foi atend...  None
# 4  Sr(a). Usuário(a),É necessário, para análise d...  None

# %%
# Selecionando apenas as colunas desejadas
df = df[['description','ownergroup','descricaodemanda','solution','SS_solucaoparausuario','Script_solucaoparausuario']]

# %%
# Mudando o nome das colunas
df.columns = ['descricao','grupo','descricao_demanda','solucao','solucao_usuario','solucao_script']
df.head()
# Out:
#                                            descricao          grupo  \
# 0  CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...  UNACDFPUCOMEX
# 1  CENTRAL DE SERVIÇOS RFB,CCT - CONTROLE DE CARG...  UNACDFPUCOMEX
# 2  CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...  CAGSBRPUCOMEX
# 3  CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...  UNACDFPUCOMEX
# 4  CENTRAL DE SERVIÇOS RFB,CCT - CONTROLE DE CARG...  UNACDFPUCOMEX
#
#                                    descricao_demanda             solucao  \
# 0  Bom Dia Tenho dois processos o qual ja voo , n...
# 1  Bom dia, Enviei uma nota para o Siscomex e seu...    2016SOL/00396862
# 2                                                       2016SOL/00399811
# 3  Srs., Fizemos várias tentativas para obter inf...    2017SOL/00003655
# 4  Nro da Solicitação: 2017SS/0001012491: Como so...  2017SOL/0000002832
#
#                                      solucao_usuario  \
# 0  Prezado Usuário\n\nAs cargas estão com a Améri...
# 1  \n\nPrezado(a) usuário(a),\nProblema resolvido...
# 2  Prezado usuario,segue a informação do nosso de...
# 3  Prezado Usuário,\n\nVocê pode estar tirando as...
# 4  Caro usuário,\n\nA DUE 17BR0000079935 já se en...
#
#                                       solucao_script
# 0                                            #N/DISP
# 1   Sr.(a) usuário(a), conforme contato telefônic...
# 2  Sr.(a) usuário(a),conforme informado através d...
# 3   \nSr(a). usuário(a),Sua solicitação foi atend...
# 4  Sr(a). Usuário(a),É necessário, para análise d...

# %%
# Exibindo estatísticas do pandas
df.describe()
# Out:
#                                                 descricao   grupo  \
# count                                               18161   18161
# unique                                                 66      34
# top     CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...  ATGSMG
# freq                                                 4216    4654
#
#        descricao_demanda solucao solucao_usuario solucao_script
# count              18161   18161           18161          18161
# unique             17059     174            9208            149
# top                                                     #N/DISP
# freq                 474    6564            2118           6737

# %%
# Removendo valores vazios em descricao_demanda
df = df.dropna(subset=['descricao_demanda']) 
df = df[df.descricao_demanda != '']
df.describe()
# Out:
#                                                 descricao   grupo  \
# count                                               17687   17687
# unique                                                 66      33
# top     CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...  ATGSMG
# freq                                                 4071    4536
#
#        descricao_demanda solucao solucao_usuario solucao_script
# count              17687   17687           17687          17687
# unique             17058     174            8918            149
# top              URGENTE                                #N/DISP
# freq                  14    6405            2067           6571

# %%
# removendo colunas indesejadas de grupo
df = df.dropna(subset=['grupo']) 
df = df[df.grupo != '']
grupos = df['grupo'].unique()
print(len(grupos))
grupos
# Out:
# 33
# array(['UNACDFPUCOMEX', 'GSDERJCCTR', 'CAGSBRPUCOMEX', 'ATGSBRTERC',
#        'ATGSMG', 'CAGSBRNOVOEX', 'CAGSBRCOMEX', 'GSDESCPLATAFORMA',
#        'GSGSSPCENTRODECOMANDO', 'GSCDSP', 'GSDERJDUEX', 'GSDESCGRIS',
#        'GSDESCTALP', 'GSGSDFCENTRODECOMANDO', 'CAGSBRTRIBUT',
#        'CAGSRSMDIC', 'GSDERJGATEWAY', 'ATGSSPRFB', 'ATGSPE', 'GSDERSOEA',
#        'CACDBRPUCOMEX', 'CAGSBRDWRFB', 'GSDERJCOAD', 'GSDERJSUCE',
#        'CAGSBRDRAWBACK', 'CACDBRCOMEX', 'GSCDSPASLGESTAOAT', 'ATGSSP',
#        'ATCDMGRAIS', 'GSOPSPSEGI', 'GSOPSPARLDI', 'CACDBRTRIBUT',
#        'ATGSBREMAIL'], dtype=object)

# %%
# Removendo quebra de linha da descricao
df['descricao'] = df['descricao'].replace(r'\n','', regex=True)
descricoes = df['descricao'].unique()
print(len(descricoes))
descricoes
# Out:
# 66
# array(['CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO,REGRA DE NEGÓCIO',
#        'CENTRAL DE SERVIÇOS RFB,CCT - CONTROLE DE CARGA E TRÂNSITO,ANÁLISE URC',
#        'CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO,ANÁLISE URC',
#        'CENTRAL DE SERVIÇOS RFB,PORTAL ÚNICO DE COMÉRCIO EXTERIOR,ANÁLISE URC',
#        'CENTRAL DE SERVIÇOS RFB,CCT - CONTROLE DE CARGA E TRÂNSITO,APLICAÇÃO',
#        'CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO,SITUAÇÃO NÃO PREVISTA',
#        'CENTRAL DE SERVIÇOS RFB,PORTAL ÚNICO DE COMÉRCIO EXTERIOR,SITUAÇÃO NÃO PREVISTA',
#        'CENTRAL DE SERVIÇOS RFB,PORTAL ÚNICO DE COMÉRCIO EXTERIOR,DÚVIDA OU INFORMAÇÕES',
#        'CENTRAL DE SERVIÇOS RFB,PORTAL ÚNICO DE COMÉRCIO EXTERIOR,APLICAÇÃO,APLICAÇÃO VIA FORM-WEB',
#        'CENTRAL DE SERVIÇOS RFB,PORTAL ÚNICO DE COMÉRCIO EXTERIOR,AMBIENTE,AMBIENTE VIA FORM-WEB',
#        'CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO,DÚVIDA OU INFORMAÇÕES',
#        'CENTRAL DE SERVIÇOS RFB,CCT - CONTROLE DE CARGA E TRÂNSITO,SITUAÇÃO NÃO PREVISTA',
#        'CENTRAL DE SERVIÇOS RFB,PORTAL ÚNICO DE COMÉRCIO EXTERIOR,APLICAÇÃO',
#        'CENTRAL DE SERVIÇOS RFB,PORTAL ÚNICO DE COMÉRCIO EXTERIOR',
#        'OEA - OPERADOR ECONÔMICO AUTORIZADO,DÚVIDA',
#        'CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO,AMBIENTE',
#        'OEA - OPERADOR ECONÔMICO AUTORIZADO,SITUAÇÃO NÃO PREVISTA',
#        'CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO,APLICAÇÃO',
#        'CENTRAL DE SERVIÇOS RFB,CCT - CONTROLE DE CARGA E TRÂNSITO',
#        'GR – GERENCIAMENTO DE RISCO ALEATÓRIOS,APLICAÇÃO',
#        'CA - CONFERÊNCIA ADUANEIRA EXPORTAÇÃO,SITUAÇÃO NÃO PREVISTA',
#        'CENTRAL DE SERVIÇOS RFB,DA - DESPACHO ADUANEIRO,SITUAÇÃO NÃO PREVISTA',
#        'CENTRAL DE SERVIÇOS RFB,PORTAL ÚNICO DE COMÉRCIO EXTERIOR,AMBIENTE',
#        'CENTRAL DE SERVIÇOS RFB,TA-LPCO - TRATAMENTO ADMIN, LICENÇAS, PERMISSÕES, CERTIFICADOS E OUTROS,APLICAÇÃO',
#        'CENTRAL DE SERVIÇOS RFB,DA - DESPACHO ADUANEIRO,HOMOLOGAÇÃO, IMPLANTAÇÃO OU TESTE',
#        'CENTRAL DE SERVIÇOS RFB,TA-LPCO - TRATAMENTO ADMIN, LICENÇAS, PERMISSÕES, CERTIFICADOS E OUTROS,DÚVIDA OU INFORMAÇÕES',
#        'CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO',
#        'CENTRAL DE SERVIÇOS RFB,CCT - CONTROLE DE CARGA E TRÂNSITO,AMBIENTE',
#        'CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO,APLICAÇÃO, Windows XP, 8 att 111, Google Chrome, siscomexc.desenvolvimento.gov.br, erro no processamento',
#        'CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO,APLICAÇÃO, Windows 7, java 8 161, Mozilla Firefox, https://siscomex.desenvolvimento.gov.br/exportacaoweb/atualizaregistroexportacao.do, não soube informar, 18/0334238-001',
#        'CENTRAL DE SERVIÇOS RFB,TA-LPCO - TRATAMENTO ADMIN, LICENÇAS, PERMISSÕES, CERTIFICADOS E OUTROS,SITUAÇÃO NÃO PREVISTA',
#        'CENTRAL DE SERVIÇOS RFB,TA-LPCO - TRATAMENTO ADMIN, LICENÇAS, PERMISSÕES, CERTIFICADOS E OUTROS,REGRA DE NEGÓCIO - ANALISE URC',
#        'GR – GERENCIAMENTO DE RISCO ALEATÓRIOS,ANÁLISE URC',
#        'CENTRAL DE SERVIÇOS RFB,PORTAL ÚNICO DE COMÉRCIO EXTERIOR,REGRA DE NEGÓCIO',
#        'CENTRAL DE SERVIÇOS RFB,CCT - CONTROLE DE CARGA E TRÂNSITO,REGRA DE NEGÓCIO',
#        'OEA - OPERADOR ECONÔMICO AUTORIZADO,APLICAÇÃO',
#        'CENTRAL DE SERVIÇOS RFB,CCT - CONTROLE DE CARGA E TRÂNSITO,DÚVIDA OU INFORMAÇÕES',
#        'CA - CONFERÊNCIA ADUANEIRA EXPORTAÇÃO,APLICAÇÃO',
#        'CENTRAL DE SERVIÇOS RFB,PORTAL ÚNICO DE COMÉRCIO EXTERIOR,HOMOLOGAÇÃO, IMPLANTAÇÃO OU TESTE',
#        'CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO,HOMOLOGAÇÃO, IMPLANTAÇÃO OU TESTE',
#        'CA - CONFERÊNCIA ADUANEIRA EXPORTAÇÃO',
#        'CENTRAL DE SERVIÇOS RFB,DA - DESPACHO ADUANEIRO',
#        'GR – GERENCIAMENTO DE RISCO ALEATÓRIOS,AMBIENTE',
#        'CENTRAL DE SERVIÇOS RFB,DA - DESPACHO ADUANEIRO,APLICAÇÃO',
#        'CENTRAL DE SERVIÇOS RFB,TA-LPCO - TRATAMENTO ADMIN, LICENÇAS, PERMISSÕES, CERTIFICADOS E OUTROS,AMBIENTE',
#        'GR – GERENCIAMENTO DE RISCO ALEATÓRIOS,SITUAÇÃO NÃO PREVISTA',
#        'GR – GERENCIAMENTO DE RISCO ALEATÓRIOS,DÚVIDA OU INFORMAÇÕES',
#        'CA - CONFERÊNCIA ADUANEIRA EXPORTAÇÃO,AMBIENTE',
#        'CENTRAL DE SERVIÇOS RFB,GR – GERENCIAMENTO DE RISCO ALEATÓRIOS,DÚVIDA OU INFORMAÇÕES',
#        'CENTRAL DE SERVIÇOS RFB,CA - CONFERÊNCIA ADUANEIRA EXPORTAÇÃO,SITUAÇÃO NÃO PREVISTA',
#        'APOIO COMUNIDADE MDIC,DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO - MDIC,SITUAÇÃO NAO PREVISTA',
#        'CENTRAL DE SERVIÇOS RFB,PROSPECÇÃO - CLASSIF - CLASSIFICAÇÃO FISCAL DE MERCADORIAS RFB,SITUAÇÃO NAO PREVISTA',
#        'CENTRAL DE SERVIÇOS RFB,PORTAL ÚNICO SISCOMEX RFB INTRANET(PUCOMEX),AMBIENTE',
#        'CENTRAL DE SERVIÇOS RFB,PORTAL ÚNICO SISCOMEX RFB INTRANET(PUCOMEX)',
#        'CENTRAL DE SERVIÇOS RFB,CA - CONFERÊNCIA ADUANEIRA EXPORTAÇÃO,AMBIENTE',
#        'CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO,SITUAÇÃO DE CRISE',
#        'CENTRAL DE SERVIÇOS MDIC,PORTAL ÚNICO SISCOMEX ANUENTES INTERNET (PUCOMEX)',
#        'APOIO COMUNIDADE MDIC,PORTAL ÚNICO SISCOMEX ANUENTES INTERNET (PUCOMEX)',
#        'CENTRAL DE SERVIÇOS RFB,CA - CONFERÊNCIA ADUANEIRA EXPORTAÇÃO,APLICAÇÃO',
#        'CENTRAL DE SERVIÇOS RFB,CADASTRO DE INTERVENIENTES - RFB,SITUAÇÃO NÃO PREVISTA',
#        'CENTRAL DE SERVIÇOS RFB,PORTAL ÚNICO SISCOMEX RFB INTRANET(PUCOMEX),SITUAÇAO NÃO PREVISTA',
#        'OEA - OPERADOR ECONÔMICO AUTORIZADO,AMBIENTE',
#        'CENTRAL DE SERVIÇOS RFB,OPERADOR ECONÔMICO AUTORIZADO (OEA) - RFB,SITUAÇÃO NAO PREVISTA',
#        'CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO - RFB,SITUAÇÃO NÃO PREVISTA',
#        'CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO - RFB,DUVIDA OU INFORMAÇÕES',
#        'CENTRAL DE SERVIÇOS MDIC,VICOMEX - VISÃO INTEGRADA DO COMÉRCIO EXTERIOR - MDIC,SITUAÇÃO NAO PREVISTA'],
#       dtype=object)

# %%
# Extraindo o segundo e terceiro termo após a vírgula
import numpy as np
df['sistema'] =  (np.where(df['descricao'].str.contains(','),
                  df['descricao'].str.split(',').str[1],
                  df['descricao']))
df['classificacao'] =  (np.where(df['descricao'].str.contains(','),
                  df['descricao'].str.split(',').str[2],
                  df['descricao']))
# Reorganizando a ordem das colunas
df = df[['sistema','classificacao','grupo', 'descricao_demanda','descricao','solucao','solucao_usuario','solucao_script']]
# Removendo valores nulos das colunas criadas
df = df.dropna(subset=['sistema','classificacao'])
df = df[df.sistema != '']
df = df[df.classificacao != '']
df.describe()
# Out:
#                                       sistema          classificacao  \
# count                                   15610                  15610
# unique                                     14                     13
# top     DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO  SITUAÇÃO NÃO PREVISTA
# freq                                     6376                   8078
#
#                 grupo descricao_demanda  \
# count           15610             15610
# unique             29             15047
# top     CACDBRPUCOMEX           URGENTE
# freq             4187                14
#
#                                                 descricao solucao  \
# count                                               15610   15610
# unique                                                 47     168
# top     CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...
# freq                                                 4071    4842
#
#        solucao_usuario solucao_script
# count            15610          15610
# unique            8298            143
# top                           #N/DISP
# freq              1636           4997

# %%
# Verificando quantos registros existem por sistema
df.groupby('sistema').count()
# Out:
#                                                     classificacao  grupo  \
# sistema
# CA - CONFERÊNCIA ADUANEIRA EXPORTAÇÃO                          60     60
# CADASTRO DE INTERVENIENTES - RFB                                1      1
# CCT - CONTROLE DE CARGA E TRÂNSITO                           3719   3719
# DA - DESPACHO ADUANEIRO                                         3      3
# DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO                        6376   6376
# DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO - MDIC                    1      1
# DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO - RFB                     2      2
# GR – GERENCIAMENTO DE RISCO ALEATÓRIOS                          1      1
# OPERADOR ECONÔMICO AUTORIZADO (OEA) - RFB                       1      1
# PORTAL ÚNICO DE COMÉRCIO EXTERIOR                            4945   4945
# PORTAL ÚNICO SISCOMEX RFB INTRANET(PUCOMEX)                    20     20
# PROSPECÇÃO - CLASSIF - CLASSIFICAÇÃO FISCAL DE ...              1      1
# TA-LPCO - TRATAMENTO ADMIN                                    478    478
# VICOMEX - VISÃO INTEGRADA DO COMÉRCIO EXTERIOR ...              2      2
#
#                                                     descricao_demanda  \
# sistema
# CA - CONFERÊNCIA ADUANEIRA EXPORTAÇÃO                              60
# CADASTRO DE INTERVENIENTES - RFB                                    1
# CCT - CONTROLE DE CARGA E TRÂNSITO                               3719
# DA - DESPACHO ADUANEIRO                                             3
# DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO                            6376
# DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO - MDIC                        1
# DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO - RFB                         2
# GR – GERENCIAMENTO DE RISCO ALEATÓRIOS                              1
# OPERADOR ECONÔMICO AUTORIZADO (OEA) - RFB                           1
# PORTAL ÚNICO DE COMÉRCIO EXTERIOR                                4945
# PORTAL ÚNICO SISCOMEX RFB INTRANET(PUCOMEX)                        20
# PROSPECÇÃO - CLASSIF - CLASSIFICAÇÃO FISCAL DE ...                  1
# TA-LPCO - TRATAMENTO ADMIN                                        478
# VICOMEX - VISÃO INTEGRADA DO COMÉRCIO EXTERIOR ...                  2
#
#                                                     descricao  solucao  \
# sistema
# CA - CONFERÊNCIA ADUANEIRA EXPORTAÇÃO                      60       60
# CADASTRO DE INTERVENIENTES - RFB                            1        1
# CCT - CONTROLE DE CARGA E TRÂNSITO                       3719     3719
# DA - DESPACHO ADUANEIRO                                     3        3
# DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO                    6376     6376
# DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO - MDIC                1        1
# DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO - RFB                 2        2
# GR – GERENCIAMENTO DE RISCO ALEATÓRIOS                      1        1
# OPERADOR ECONÔMICO AUTORIZADO (OEA) - RFB                   1        1
# PORTAL ÚNICO DE COMÉRCIO EXTERIOR                        4945     4945
# PORTAL ÚNICO SISCOMEX RFB INTRANET(PUCOMEX)                20       20
# PROSPECÇÃO - CLASSIF - CLASSIFICAÇÃO FISCAL DE ...          1        1
# TA-LPCO - TRATAMENTO ADMIN                                478      478
# VICOMEX - VISÃO INTEGRADA DO COMÉRCIO EXTERIOR ...          2        2
#
#                                                     solucao_usuario  \
# sistema
# CA - CONFERÊNCIA ADUANEIRA EXPORTAÇÃO                            60
# CADASTRO DE INTERVENIENTES - RFB                                  1
# CCT - CONTROLE DE CARGA E TRÂNSITO                             3719
# DA - DESPACHO ADUANEIRO                                           3
# DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO                          6376
# DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO - MDIC                      1
# DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO - RFB                       2
# GR – GERENCIAMENTO DE RISCO ALEATÓRIOS                            1
# OPERADOR ECONÔMICO AUTORIZADO (OEA) - RFB                         1
# PORTAL ÚNICO DE COMÉRCIO EXTERIOR                              4945
# PORTAL ÚNICO SISCOMEX RFB INTRANET(PUCOMEX)                      20
# PROSPECÇÃO - CLASSIF - CLASSIFICAÇÃO FISCAL DE ...                1
# TA-LPCO - TRATAMENTO ADMIN                                      478
# VICOMEX - VISÃO INTEGRADA DO COMÉRCIO EXTERIOR ...                2
#
#                                                     solucao_script
# sistema
# CA - CONFERÊNCIA ADUANEIRA EXPORTAÇÃO                           60
# CADASTRO DE INTERVENIENTES - RFB                                 1
# CCT - CONTROLE DE CARGA E TRÂNSITO                            3719
# DA - DESPACHO ADUANEIRO                                          3
# DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO                         6376
# DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO - MDIC                     1
# DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO - RFB                      2
# GR – GERENCIAMENTO DE RISCO ALEATÓRIOS                           1
# OPERADOR ECONÔMICO AUTORIZADO (OEA) - RFB                        1
# PORTAL ÚNICO DE COMÉRCIO EXTERIOR                             4945
# PORTAL ÚNICO SISCOMEX RFB INTRANET(PUCOMEX)                     20
# PROSPECÇÃO - CLASSIF - CLASSIFICAÇÃO FISCAL DE ...               1
# TA-LPCO - TRATAMENTO ADMIN                                     478
# VICOMEX - VISÃO INTEGRADA DO COMÉRCIO EXTERIOR ...               2

# %%
# Escolhendo um sistema para a POC
SISTEMA_SELECIONADO = 'DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO'
df = df.loc[df['sistema'] == SISTEMA_SELECIONADO]
# Mostrando quandos existem por classificacao
df.groupby('classificacao').count()
# Out:
#                        sistema  grupo  descricao_demanda  descricao  solucao  \
# classificacao
# AMBIENTE                   362    362                362        362      362
# ANÁLISE URC                130    130                130        130      130
# APLICAÇÃO                  471    471                471        471      471
# DÚVIDA OU INFORMAÇÕES     1258   1258               1258       1258     1258
# HOMOLOGAÇÃO                  1      1                  1          1        1
# REGRA DE NEGÓCIO            81     81                 81         81       81
# SITUAÇÃO DE CRISE            2      2                  2          2        2
# SITUAÇÃO NÃO PREVISTA     4071   4071               4071       4071     4071
#
#                        solucao_usuario  solucao_script
# classificacao
# AMBIENTE                           362             362
# ANÁLISE URC                        130             130
# APLICAÇÃO                          471             471
# DÚVIDA OU INFORMAÇÕES             1258            1258
# HOMOLOGAÇÃO                          1               1
# REGRA DE NEGÓCIO                    81              81
# SITUAÇÃO DE CRISE                    2               2
# SITUAÇÃO NÃO PREVISTA             4071            4071

# %%
# Removendo classificaoes com menos que X excemplos
MINIMO_REGISTROS = 50
counts = df['classificacao'].value_counts()
df = df[df['classificacao'].isin(counts[counts > MINIMO_REGISTROS].index)]
df.groupby('classificacao').count()
# Out:
#                        sistema  grupo  descricao_demanda  descricao  solucao  \
# classificacao
# AMBIENTE                   362    362                362        362      362
# ANÁLISE URC                130    130                130        130      130
# APLICAÇÃO                  471    471                471        471      471
# DÚVIDA OU INFORMAÇÕES     1258   1258               1258       1258     1258
# REGRA DE NEGÓCIO            81     81                 81         81       81
# SITUAÇÃO NÃO PREVISTA     4071   4071               4071       4071     4071
#
#                        solucao_usuario  solucao_script
# classificacao
# AMBIENTE                           362             362
# ANÁLISE URC                        130             130
# APLICAÇÃO                          471             471
# DÚVIDA OU INFORMAÇÕES             1258            1258
# REGRA DE NEGÓCIO                    81              81
# SITUAÇÃO NÃO PREVISTA             4071            4071

# %%
df2 = df[df.classificacao == 'SITUAÇÃO NÃO PREVISTA']
df = df[df.classificacao != 'SITUAÇÃO NÃO PREVISTA']
df.groupby('classificacao').count()
# Out:
#                        sistema  grupo  descricao_demanda  descricao  solucao  \
# classificacao
# AMBIENTE                   362    362                362        362      362
# ANÁLISE URC                130    130                130        130      130
# APLICAÇÃO                  471    471                471        471      471
# DÚVIDA OU INFORMAÇÕES     1258   1258               1258       1258     1258
# REGRA DE NEGÓCIO            81     81                 81         81       81
#
#                        solucao_usuario  solucao_script
# classificacao
# AMBIENTE                           362             362
# ANÁLISE URC                        130             130
# APLICAÇÃO                          471             471
# DÚVIDA OU INFORMAÇÕES             1258            1258
# REGRA DE NEGÓCIO                    81              81

# %%
df2.groupby('classificacao').count()
# Out:
#                        sistema  grupo  descricao_demanda  descricao  solucao  \
# classificacao
# SITUAÇÃO NÃO PREVISTA     4071   4071               4071       4071     4071
#
#                        solucao_usuario  solucao_script
# classificacao
# SITUAÇÃO NÃO PREVISTA             4071            4071

# %%
classificacoes = df['classificacao'].unique()
print(len(classificacoes))
classificacoes
# Out:
# 5
# array(['REGRA DE NEGÓCIO', 'ANÁLISE URC', 'DÚVIDA OU INFORMAÇÕES',
#        'AMBIENTE', 'APLICAÇÃO'], dtype=object)

# %%
df.head()
# Out:
#                                   sistema     classificacao          grupo  \
# 0   DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO  REGRA DE NEGÓCIO  UNACDFPUCOMEX
# 3   DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO  REGRA DE NEGÓCIO  UNACDFPUCOMEX
# 5   DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO       ANÁLISE URC  UNACDFPUCOMEX
# 9   DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO       ANÁLISE URC  UNACDFPUCOMEX
# 11  DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO  REGRA DE NEGÓCIO  UNACDFPUCOMEX
#
#                                     descricao_demanda  \
# 0   Bom Dia Tenho dois processos o qual ja voo , n...
# 3   Srs., Fizemos várias tentativas para obter inf...
# 5   Recepcionamos a DUE 17BR0000257710, porem nao ...
# 9   A cia aérea não consegue averbar a DUE 17BR000...
# 11  GOSTARIA DE DETALHES DO MOTIVO DA NÃO AVERBAÇÃ...
#
#                                             descricao             solucao  \
# 0   CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...
# 3   CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...    2017SOL/00003655
# 5   CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...
# 9   CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...  2017SOL/0000002832
# 11  CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...    2016SOL/00397182
#
#                                       solucao_usuario  \
# 0   Prezado Usuário\n\nAs cargas estão com a Améri...
# 3   Prezado Usuário,\n\nVocê pode estar tirando as...
# 5   Caro Usuário,\n\nFavor informar a chave da not...
# 9   \nPrezado(a) Usuário(a),\n\nA DUE encontra-se ...
# 11  Prezado Usuário,\n\nO manifestador precisa ret...
#
#                                        solucao_script
# 0                                             #N/DISP
# 3    \nSr(a). usuário(a),Sua solicitação foi atend...
# 5                                             #N/DISP
# 9   Sr(a). Usuário(a),É necessário, para análise d...
# 11  Prezado(a) usuário(a),conforme informado atrav...

# %% [markdown]
# ## Preparação dos dados

# %%
# Estrutura para armazenar pontuações
tbl = dict.fromkeys(i for i in range(sys.maxunicode) if unicodedata.category(chr(i)).startswith('P'))
# Função para remover pontuações das sentenças
def remove_punctuation(text):
    return text.translate(tbl)

# %%
# Lista de palavras para inluir com regex
INCLUDE_WORDS_BY_REGEX = [r"^[A-Za-zçãàáâéêíóôõúüÂÃÁÀÉÊÍÓÔÕÚÜÇ'º°ª\.]*$",r"^[0-9\-/\\\.]*$"]
def include_words_by_regex(words):
    # Remove regex words
    words_aux = []
    for word in words:
        add = False
        for regex_exp in INCLUDE_WORDS_BY_REGEX:
            if re.compile(regex_exp).match(word):
                add = True
        if add:
            words_aux.append(word)
    return words_aux       
# Padroes regex para serem removidos do texto original
REMOVE_WORDS_BY_REGEX = [r"\S*@\S*\s?", # Email
    r"(http:\/\/www\.|https:\/\/www\.|http:\/\/|https:\/\/)?[a-z0-9]+([\-\.]{1}[a-z0-9]+)*\.[a-z]{2,5}(:[0-9]{1,5})?(\/[a-z0-9]*)*(\/)?", # Site
    r"([a-z0-9]+(\/)[a-z0-9]+)", # Protocolo
    r"(\(?\d{2,4}\)?)??[\-\s\.]?(\d{3,5})[\.\-]\d{4,5}", # Telefone
    r"\d{2}[\-\s\.]\d{4}", # Ramal
    r"([0-9]{2}[\.]?[0-9]{3}[\.]?[0-9]{3}[\/]?[0-9]{4}[-]?[0-9]{2})|([0-9]{3}[\.]?[0-9]{3}[\.]?[0-9]{3}[-]?[0-9]{2})", # CPF e CNPJ
    r"\d+" # Numeros
    #r"e-?mail:?" # texto email/e-mail
]
def remove_words_by_regex(text):
    for regex_exp in REMOVE_WORDS_BY_REGEX:
        text = re.sub(re.compile(regex_exp),"",text)
    return text
# Padroes regex para remoção do conteúdo a seguir
REMOVE_TEXT_AFTER_REGEX = [
        r"o acesso ao conte(u|ú)do desta mensagem",
        r"aviso legal",
        r"esta mensagem (e|é) destinada exclusivamente",
        r"legal advice",
        r"this message is exclusively destined"
]
def remove_text_after_regex(text):
    for regex_exp in REMOVE_TEXT_AFTER_REGEX:
        m = re.search(regex_exp, text)
        if m:
            text = text[:m.start()]
    return text

# %%
text = """"
srs., fizemos várias tentativas para obter informações em relação à adesão 
ao portal due, alguns exemplos: primeiramente acessamos o site: 
http://www.serpro.gov.br/menu/contato/cliente/ depois por telefone: 
0800-728-2323 e também nos contatos: 
sccd@serpro.gov.br<mailto:sccd@serpro.gov.br> 
http://comexresponde.comexbrasil.gov.br/ - protocolo: 30696 em uma das 
orientações recebidas (protocolo nº 2017ss/0000973710), nos informaram que 
o acesso seria através do mdic / comex, procedemos de acordo, porém não 
houve retorno. por favor, precisamos do contato urgente para alinhamento. 
favor contatar: fernanda cezar no telefone:3646-2256 / e-mail: 
fernanda.cezar@bradesco.com.br gratos. atenciosamente. banco bradesco s/a 
4861 / droc – departamento de relacionamento operacional com clientes setor 
apoio a projetos patrícia vidal tel: (11) 2646-3320 r: 31-3320 
classificação: interna “o acesso ao conteúdo desta mensagem está 
autorizado, exclusivamente, a colaboradores da organização bradesco. a 
reprodução a pessoas não enquadradas deve ser autorizada pelo gestor da 
informação, para identificá-lo contate o remetente". 
[cid:image164146.png@3690fe11.49984c89] aviso legal
...esta mensagem é destinada exclusivamente para a(s) pessoa(s) a quem é 
dirigida, podendo conter informação confidencial e/ou legalmente 
privilegiada. se você não for destinatário desta mensagem, desde já fica 
notificado de abster-se a divulgar, copiar, distribuir, examinar ou, de 
qualquer forma, utilizar a informação contida nesta mensagem, por ser 
ilegal. caso você tenha recebido esta mensagem por engano, pedimos que nos 
retorne este e-mail, promovendo, desde logo, a eliminação do seu conteúdo 
em sua base de dados, registros ou sistema de controle. fica desprovida de 
eficácia e validade a mensagem que contiver vínculos obrigacionais, 
expedida por quem não detenha poderes de representação. legal advice
...this message is exclusively destined for the people to whom it is 
directed, and it can bear private and/or legally exceptional information. 
if you are not addressee of this message, since now you are advised to not 
release, copy, distribute, check or, otherwise, use the information 
contained in this message, because it is illegal. if you received this 
message by mistake, we ask you to return this email, making possible, as 
soon as possible, the elimination of its contents of your database, 
registrations or controls system. the message that bears any mandatory 
links, issued by someone who has no representation powers, shall be null or 
void. [screenshot 1 saved as attachment image1641461512409665054.png by 
e-mail listener.]
"""
text = remove_words_by_regex(text.lower())
print(text)
text2 = remove_text_after_regex(text)
print(text2)
# Out:
# "
# srs., fizemos várias tentativas para obter informações em relação à adesão
# ao portal due, alguns exemplos: primeiramente acessamos o site:
#  depois por telefone:
#  e também nos contatos:
#
#  - protocolo:  em uma das
# orientações recebidas (protocolo nº ), nos informaram que
# o acesso seria através do mdic / comex, procedemos de acordo, porém não
# houve retorno. por favor, precisamos do contato urgente para alinhamento.
# favor contatar: fernanda cezar no telefone: / e-mail:
# gratos. atenciosamente. banco bradesco
#  / droc – departamento de relacionamento operacional com clientes setor
# apoio a projetos patrícia vidal tel:  r:
# classificação: interna “o acesso ao conteúdo desta mensagem está
# autorizado, exclusivamente, a colaboradores da organização bradesco. a
# reprodução a pessoas não enquadradas deve ser autorizada pelo gestor da
# informação, para identificá-lo contate o remetente".
# aviso legal
# ...esta mensagem é destinada exclusivamente para a(s) pessoa(s) a quem é
# dirigida, podendo conter informação confidencial  legalmente
# privilegiada. se você não for destinatário desta mensagem, desde já fica
# notificado de abster-se a divulgar, copiar, distribuir, examinar ou, de
# qualquer forma, utilizar a informação contida nesta mensagem, por ser
# ilegal. caso você tenha recebido esta mensagem por engano, pedimos que nos
# retorne este e-mail, promovendo, desde logo, a eliminação do seu conteúdo
# em sua base de dados, registros ou sistema de controle. fica desprovida de
# eficácia e validade a mensagem que contiver vínculos obrigacionais,
# expedida por quem não detenha poderes de representação. legal advice
# ...this message is exclusively destined for the people to whom it is
# directed, and it can bear private  legally exceptional information.
# if you are not addressee of this message, since now you are advised to not
# release, copy, distribute, check or, otherwise, use the information
# contained in this message, because it is illegal. if you received this
# message by mistake, we ask you to return this email, making possible, as
# soon as possible, the elimination of its contents of your database,
# registrations or controls system. the message that bears any mandatory
# links, issued by someone who has no representation powers, shall be null or
# void. [screenshot  saved as attachment  by
# e-mail listener.]
#
# "
# srs., fizemos várias tentativas para obter informações em relação à adesão
# ao portal due, alguns exemplos: primeiramente acessamos o site:
#  depois por telefone:
#  e também nos contatos:
#
#  - protocolo:  em uma das
# orientações recebidas (protocolo nº ), nos informaram que
# o acesso seria através do mdic / comex, procedemos de acordo, porém não
# houve retorno. por favor, precisamos do contato urgente para alinhamento.
# favor contatar: fernanda cezar no telefone: / e-mail:
# gratos. atenciosamente. banco bradesco
#  / droc – departamento de relacionamento operacional com clientes setor
# apoio a projetos patrícia vidal tel:  r:
# classificação: interna “

# %%
spacy_pln = spacy.load('pt_core_news_sm')
words = [token.lemma_ for token in spacy_pln(text2)]
print (words)
# Out:
# ['"', '\n', 'sr', '.', ',', 'fazer', 'vários', 'tentativo', 'parir', 'obter', 'informação', 'em', 'relação', 'à', 'adesão', '\n', 'o', 'o', 'portal', 'due', ',', 'algum', 'exemplo', ':', 'primeiramente', 'acessamos', 'o', 'site', ':', '\n ', 'depois', 'por', 'telefonar', ':', '\n ', 'e', 'também', 'o', 'contatos', ':', '\n\n ', '-', 'protocolo', ':', ' ', 'em', 'umar', 'das', '\n', 'orientação', 'recebido', '(', 'protocolo', 'nº', ')', ',', 'o', 'informar', 'que', '\n', 'o', 'acesso', 'seriar', 'através', 'do', 'mdic', '/', 'comex', ',', 'proceder', 'de', 'acordar', ',', 'porém', 'não', '\n', 'haver', 'retornar', '.', 'por', 'favor', ',', 'precisar', 'do', 'contato', 'urgente', 'parir', 'alinhamento', '.', '\n', 'favor', 'contatar', ':', 'fernanda', 'cezar', 'o', 'telefonar', ':', '/', 'e', '-', 'mail', ':', '\n', 'grato', '.', 'atenciosamente', '.', 'banco', 'bradesco', ' \n ', '/', 'droc', '–', 'departamento', 'de', 'relacionamento', 'operacional', 'com', 'cliente', 'setor', '\n', 'apoiar', 'o', 'projetos', 'patrício', 'vidal', 'tel', ':', ' ', 'r', ':', ' \n', 'classificação', ':', 'interno', '“']

# %%
spacy_pln = spacy.load('pt_core_news_sm')
# Função para realizar o pré-processamento do texto livre
# Inicializa o stemmer
#stemmer = LancasterStemmer() 
stemmer = RSLPStemmer()
# Stop words para o Português
portuguese_stops = set(stopwords.words('portuguese'))
portuguese_stops.update('é')
REMOVER = ['attach','email']
LIMITE_TAMANHO_PALAVRA = 2
# Dicionátio que armazena as pontuações a serem removidas
def preprocessing(content):
    # Converte para minúsculo
    content = content.lower()
    # Remove elementos do texto via REGEX
    content = remove_words_by_regex(content)
    content = remove_text_after_regex(content)
    #Remover pontuação
    content = remove_punctuation(content)
    # Tokenização
    words = tokenize.word_tokenize(content, language='portuguese')
    #words = [token.lemma_ for token in spacy_pln(content)]
    # Remover acentuação
    words = [normalize('NFKD', word).encode('ASCII', 'ignore').decode('ASCII') for word in words]
    # Remove stopwords
    words = [word for word in words if word.lower() not in portuguese_stops] 
    # Stemming de cada palavra
    words = [stemmer.stem(w) for w in words if w.strip()] 
    # Remove palavras menores que um limite
    words = [word for word in words if len(word) > LIMITE_TAMANHO_PALAVRA] 
    # Remove by regex
    words = include_words_by_regex(words)
    # Remove specific words
    words = [word for word in words if word not in REMOVER] 
    return ' '.join(words)

# %%
# Imprimindo alguns exemplos
for sample in df['descricao_demanda'].head(5):
    print('============================================================================')
    print(sample)
    print('----------------------------------------------------------------------------')
    print(preprocessing(sample))
# Out:
# ============================================================================
# Bom Dia Tenho dois processos o qual ja voo , nao conseguimos concluir a
# manifestacao os dados foram informados ,porem na ultima te (resumo) ela nao
# conclui, permanece na mesma, sem efetuar a manifestacao, sendo que a mesma
# ja saiu do estoque, ja esta desembaracada e ja voou. Oa AWBS e DUES
# respectivos sao 00174790763 (DUE 17BR0000049343) e 00174790660
# (DUE17BR0000043760) , ambos na mesma situacao. DATA 13-11-2017 HORARIO: 10
# 40 [Attachment portalunico_siscomex_gov_br_cctPRINT3431510576873800.pdf
# processed by e-mail listener.] [Attachment
# portalunico_siscomex_gov_br_cctPRINT7601510576875486.pdf processed by
# e-mail listener.]
# ----------------------------------------------------------------------------
# bom dia doi process voo nao consegu conclu manifestaca dad inform por ult resum nao conclu permanec mesm efetu manifestaca send mesm saiu estoqu desembarac voou awb due respec sao due duebr ambos mesm situaca dat horari attachment portalunicosiscomexgovbr processed listen attachment portalunicosiscomexgovbr processed listen
# ============================================================================
# Srs., Fizemos várias tentativas para obter informações em relação à adesão
# ao Portal DUE, alguns exemplos: Primeiramente acessamos o site:
# http://www.serpro.gov.br/menu/contato/cliente/ Depois por telefone:
# 0800-728-2323 E também nos contatos:
# sccd@serpro.gov.br<mailto:sccd@serpro.gov.br>
# http://comexresponde.comexbrasil.gov.br/ - protocolo: 30696 Em uma das
# orientações recebidas (protocolo nº 2017SS/0000973710), nos informaram que
# o acesso seria através do MDIC / COMEX, procedemos de acordo, porém não
# houve retorno. Por favor, precisamos do contato urgente para alinhamento.
# Favor contatar: Fernanda Cezar no telefone: 3646-2256 / e-mail:
# fernanda.cezar@bradesco.com.br Gratos. Atenciosamente. BANCO BRADESCO S/A
# 4861 / DROC – Departamento de Relacionamento Operacional com Clientes Setor
# Apoio a Projetos Patrícia Vidal Tel: (11) 2646-3320 R: 31-3320
# Classificação: INTERNA “O acesso ao conteúdo desta mensagem está
# autorizado, exclusivamente, a Colaboradores da Organização Bradesco. A
# reprodução a pessoas não enquadradas deve ser autorizada pelo Gestor da
# Informação, para identificá-lo contate o remetente".
# [cid:image164146.PNG@3690fe11.49984c89] AVISO LEGAL
# ...Esta mensagem é destinada exclusivamente para a(s) pessoa(s) a quem é
# dirigida, podendo conter informação confidencial e/ou legalmente
# privilegiada. Se você não for destinatário desta mensagem, desde já fica
# notificado de abster-se a divulgar, copiar, distribuir, examinar ou, de
# qualquer forma, utilizar a informação contida nesta mensagem, por ser
# ilegal. Caso você tenha recebido esta mensagem por engano, pedimos que nos
# retorne este E-Mail, promovendo, desde logo, a eliminação do seu conteúdo
# em sua base de dados, registros ou sistema de controle. Fica desprovida de
# eficácia e validade a mensagem que contiver vínculos obrigacionais,
# expedida por quem não detenha poderes de representação. LEGAL ADVICE
# ...This message is exclusively destined for the people to whom it is
# directed, and it can bear private and/or legally exceptional information.
# If you are not addressee of this message, since now you are advised to not
# release, copy, distribute, check or, otherwise, use the information
# contained in this message, because it is illegal. If you received this
# message by mistake, we ask you to return this email, making possible, as
# soon as possible, the elimination of its contents of your database,
# registrations or controls system. The message that bears any mandatory
# links, issued by someone who has no representation powers, shall be null or
# void. [Screenshot 1 saved as attachment image1641461512409665054.PNG by
# e-mail listener.]
# ----------------------------------------------------------------------------
# fiz var tent obt informaco relaca adesa port due algum exempl prime acess sit telefon tamb contat protocol orientaco receb protocol inform acess atrav mdic comex proced acord por nao retorn favor precis contat urgent alinh favor contat fernand cez telefon grat atencios banc brad droc departament relacion operac client set apoi projet patric vidal tel classificaca intern
# ============================================================================
# Recepcionamos a DUE 17BR0000257710, porem nao esta seguindo com o
# Desembaraço
# ----------------------------------------------------------------------------
# recepcion due por nao segu desembarac
# ============================================================================
# A cia aérea não consegue averbar a DUE 17BR000025772-8 pois aparece o peso
# incorreto.
# ----------------------------------------------------------------------------
# cia aere nao conseg averb due poi aparec pes incorret
# ============================================================================
# GOSTARIA DE DETALHES DO MOTIVO DA NÃO AVERBAÇÃO DA DUE 17BR0000276145 UMA
# VEZ QUE TODAS AS INFPORMAÇÕES FORAM DEVIDAMENTE MANIFESTADAS CONFORME
# MERCANTE.
# ----------------------------------------------------------------------------
# gost detalh motiv nao averbaca due vez tod infpormaco devid manifest conform merc

# %%
# Aplicando o pre-processamento
print('Iniciando a preparação das colunas textuais...')
start_time = time.time()
df['descricao_demanda2'] = df['descricao_demanda'].apply(preprocessing)
print('Processou a coluna descricao_demanda2 em %.2f segundos' % (time.time() - start_time))
start_time = time.time()
df['solucao_usuario2'] = df['solucao_usuario'].apply(preprocessing)
print('Processou a coluna solucao_usuario2 em %.2f segundos' % (time.time() - start_time))
start_time = time.time()
df['solucao_script2'] = df['solucao_script'].apply(preprocessing)
print('Processou a coluna solucao_script2 em %.2f segundos' % (time.time() - start_time))
# Combinando a classificação e grupo
df['classificacao_grupo'] = df['classificacao'].astype(str) + ' - ' + df['grupo'].astype(str)
df.head()
# Out:
# Iniciando a preparação das colunas textuais...
# Processou a coluna descricao_demanda2 em 4.30 segundos
# Processou a coluna solucao_usuario2 em 3.97 segundos
# Processou a coluna solucao_script2 em 4.45 segundos
#                                   sistema     classificacao          grupo  \
# 0   DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO  REGRA DE NEGÓCIO  UNACDFPUCOMEX
# 3   DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO  REGRA DE NEGÓCIO  UNACDFPUCOMEX
# 5   DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO       ANÁLISE URC  UNACDFPUCOMEX
# 9   DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO       ANÁLISE URC  UNACDFPUCOMEX
# 11  DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO  REGRA DE NEGÓCIO  UNACDFPUCOMEX
#
#                                     descricao_demanda  \
# 0   Bom Dia Tenho dois processos o qual ja voo , n...
# 3   Srs., Fizemos várias tentativas para obter inf...
# 5   Recepcionamos a DUE 17BR0000257710, porem nao ...
# 9   A cia aérea não consegue averbar a DUE 17BR000...
# 11  GOSTARIA DE DETALHES DO MOTIVO DA NÃO AVERBAÇÃ...
#
#                                             descricao             solucao  \
# 0   CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...
# 3   CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...    2017SOL/00003655
# 5   CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...
# 9   CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...  2017SOL/0000002832
# 11  CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...    2016SOL/00397182
#
#                                       solucao_usuario  \
# 0   Prezado Usuário\n\nAs cargas estão com a Améri...
# 3   Prezado Usuário,\n\nVocê pode estar tirando as...
# 5   Caro Usuário,\n\nFavor informar a chave da not...
# 9   \nPrezado(a) Usuário(a),\n\nA DUE encontra-se ...
# 11  Prezado Usuário,\n\nO manifestador precisa ret...
#
#                                        solucao_script  \
# 0                                             #N/DISP
# 3    \nSr(a). usuário(a),Sua solicitação foi atend...
# 5                                             #N/DISP
# 9   Sr(a). Usuário(a),É necessário, para análise d...
# 11  Prezado(a) usuário(a),conforme informado atrav...
#
#                                    descricao_demanda2  \
# 0   bom dia doi process voo nao consegu conclu man...
# 3   fiz var tent obt informaco relaca adesa port d...
# 5               recepcion due por nao segu desembarac
# 9   cia aere nao conseg averb due poi aparec pes i...
# 11  gost detalh motiv nao averbaca due vez tod inf...
#
#                  classificacao_grupo  \
# 0   REGRA DE NEGÓCIO - UNACDFPUCOMEX
# 3   REGRA DE NEGÓCIO - UNACDFPUCOMEX
# 5        ANÁLISE URC - UNACDFPUCOMEX
# 9        ANÁLISE URC - UNACDFPUCOMEX
# 11  REGRA DE NEGÓCIO - UNACDFPUCOMEX
#
#                                      solucao_usuario2  \
# 0   prez usuari carg esta american airlin american...
# 3   prez usuari voc pod est tir duvid tiag barbosa...
# 5   car usuari favor inform chav not fiscal recepc...
# 9   prezado usuario due encontras averb atencios c...
# 11  prez usuari manifest precis retific algum cois...
#
#                                       solucao_script2
# 0
# 3   sra usuarioasu solicitaca iosamentecentr serv rfb
# 5
# 9   sra usuarioa necessari analis situaca acess pa...
# 11  prezado usuarioaconform inform atrav contat te...

# %%
df.describe()
# Out:
#                                       sistema          classificacao   grupo  \
# count                                    2302                   2302    2302
# unique                                      1                      5      17
# top     DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO  DÚVIDA OU INFORMAÇÕES  ATGSMG
# freq                                     2302                   1258     903
#
#                                         descricao_demanda  \
# count                                                2302
# unique                                               2263
# top      Usuário contatou o 0800 de atendimento SISCOM...
# freq                                                    6
#
#                                                 descricao solucao  \
# count                                                2302    2302
# unique                                                  7      62
# top     CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...
# freq                                                 1258     456
#
#                                           solucao_usuario solucao_script  \
# count                                                2302           2302
# unique                                                840             51
# top      \nSr(a) usuário(a),\n\nInformamos que no ende...        #N/DISP
# freq                                                  146            485
#
#                                        descricao_demanda2  \
# count                                                2302
# unique                                               2188
# top     usuari contat atend siscomex por encerr ligaca...
# freq                                                   18
#
#                    classificacao_grupo  \
# count                             2302
# unique                              32
# top     DÚVIDA OU INFORMAÇÕES - ATGSMG
# freq                               899
#
#                                          solucao_usuario2 solucao_script2
# count                                                2302            2302
# unique                                                739              45
# top     sra usuario inform enderec introdu const tod i...
# freq                                                  160             485

# %%
FILENAME = 'dataframe.pickle'
df.to_pickle(FILENAME)
print('arquivo salvo com sucesso!')
# Out:
# arquivo salvo com sucesso!

# %% [markdown]
# FIM

# %%
# Aplicando o pre-processamento
print('Iniciando a preparação das colunas textuais...')
start_time = time.time()
df2['descricao_demanda2'] = df2['descricao_demanda'].apply(preprocessing)
print('Processou a coluna descricao_demanda2 em %.2f segundos' % (time.time() - start_time))
start_time = time.time()
df2['solucao_usuario2'] = df2['solucao_usuario'].apply(preprocessing)
print('Processou a coluna solucao_usuario2 em %.2f segundos' % (time.time() - start_time))
start_time = time.time()
df2['solucao_script2'] = df2['solucao_script'].apply(preprocessing)
print('Processou a coluna solucao_script2 em %.2f segundos' % (time.time() - start_time))
# Combinando a classificação e grupo
df2['classificacao_grupo'] = df2['classificacao'].astype(str) + ' - ' + df2['grupo'].astype(str)
df2.head()
# Out:
# Iniciando a preparação das colunas textuais...
# Processou a coluna descricao_demanda2 em 9.63 segundos
# Processou a coluna solucao_usuario2 em 5.85 segundos
# Processou a coluna solucao_script2 em 3.28 segundos
#                                   sistema          classificacao  \
# 10  DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO  SITUAÇÃO NÃO PREVISTA
# 12  DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO  SITUAÇÃO NÃO PREVISTA
# 23  DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO  SITUAÇÃO NÃO PREVISTA
# 26  DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO  SITUAÇÃO NÃO PREVISTA
# 27  DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO  SITUAÇÃO NÃO PREVISTA
#
#             grupo                                  descricao_demanda  \
# 10  CAGSBRPUCOMEX  Bom dia, ao tentarmos retificar a Due no porta...
# 12  CAGSBRPUCOMEX  Sem acesso a criação de DU-E, opção de Embarqu...
# 23  CAGSBRPUCOMEX  Bom dia, Conforme contato telefônico no qual f...
# 26  CAGSBRPUCOMEX  O sistema está passando por uma indisponibilid...
# 27   CAGSBRNOVOEX                              Erro ao consultar DUE
#
#                                             descricao             solucao  \
# 10  CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...  2017SOL/0000002898
# 12  CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...    2016SOL/00397102
# 23  CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...    2017SOL/00003655
# 26  CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...  2017SOL/0000006065
# 27  CENTRAL DE SERVIÇOS RFB,DUEX - DECLARAÇÃO ÚNIC...    2016SOL/00400731
#
#                                       solucao_usuario  \
# 10  Favor solicitar a\nreexecução da funcionalidad...
# 12  Prezado usuario,segue a informação do nosso de...
# 23  Prezado Edson,\nBom dia!\nA versão mais nova d...
# 26  Prezado Rafael,\nBoa tarde!\nConforme contato,...
# 27                                               \n\n
#
#                                        solucao_script  \
# 10  Sr(a). Usuário(a),Para análise da situação, é ...
# 12   Sr(a). usuário(a), conforme informado através...
# 23   \nSr(a). usuário(a),Sua solicitação foi atend...
# 26  p {\nmargin-bottom: 0.21cm;\n}\na:link {\n}\n\...
# 27   Sr(a) Usuário(a), A fim de darmos continuidad...
#
#                                    descricao_demanda2  \
# 10  bom dia tent retific due port receb err inform...
# 12  acess criaca due opca embarqu antecip vinculac...
# 23  bom dia conform contat telefon ger protocol se...
# 26  sistem pass indisponibil momentane possi agu a...
# 27                                    err consult due
#
#                                      solucao_usuario2  \
# 10  favor solic reexecuca funcional poi ambi dispo...
# 12  prez usuarioseg informaca desenvolv problem an...
# 23  prez edson bom dia versa nov due produca hoj d...
# 26  prez rafael boa tard conform contat document c...
# 27
#
#                                       solucao_script2  \
# 10  sra usuarioap analis situaca necessari acess p...
# 12  sra usuario conform inform atrav contat telefo...
# 23  sra usuarioasu solicitaca iosamentecentr serv rfb
# 26  marginbottom alink sra usuarioasu solicitaca i...
# 27  sra usuario fim darm continu demand solicit ut...
#
#                       classificacao_grupo
# 10  SITUAÇÃO NÃO PREVISTA - CAGSBRPUCOMEX
# 12  SITUAÇÃO NÃO PREVISTA - CAGSBRPUCOMEX
# 23  SITUAÇÃO NÃO PREVISTA - CAGSBRPUCOMEX
# 26  SITUAÇÃO NÃO PREVISTA - CAGSBRPUCOMEX
# 27   SITUAÇÃO NÃO PREVISTA - CAGSBRNOVOEX

# %%
FILENAME2 = 'dataframe2.pickle'
df2.to_pickle(FILENAME2)
print('arquivo salvo com sucesso!')
# Out:
# arquivo salvo com sucesso!
