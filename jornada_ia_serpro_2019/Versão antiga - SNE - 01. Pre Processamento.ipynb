# %% [markdown]
# # POC SNE - Atendimento Serpro

# %% [markdown]
# ## Instalação de pacotes necessários

# %%
# Importações básicas - Descomentar as linhas abaixo:
#!pip install pandas
#!pip install tensorflow
#!pip install keras
#!pip install scikit-learn
#!pip install nltk
#!pip install ezodf
#!pip install lxml
#import nltk
#nltk.download('all')
#!pip install spacy
#!python -m spacy download pt_core_news_sm

# %% [markdown]
# ## Importações e criação de funções

# %%
import ezodf
import pandas as pd
import sys
import unicodedata
import re
import time
import spacy
import pickle
from unicodedata import normalize
from nltk.util import ngrams
from nltk import tokenize # Tokenização
from nltk.corpus import stopwords # Stopwords
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem import RSLPStemmer
# Função para mostrar as planilhas do documento
def show_ods_sheets(filename):
    doc = ezodf.opendoc(filename)
    print("Spreadsheet contains %d sheet(s)." % len(doc.sheets))
    for sheet in doc.sheets:
        print("-"*40)
        print("   Sheet name : '%s'" % sheet.name)
        print("Size of Sheet : (rows=%d, cols=%d)" % (sheet.nrows(), sheet.ncols()) )
# Função para converter ODS em DataFrame do Pandas
def read_sheet_ods_as_panda_dataframe(filename, sheet_no=0, header=0):
    tab = ezodf.opendoc(filename=filename).sheets[sheet_no]
    return pd.DataFrame({col[header].value:[x.value for x in col[header+1:]]
                         for col in tab.columns()})

# %% [markdown]
# ## Abrindo o arquivo como um DataFrame

# %%
# Exibindo informações sobre o arquivo ODS
FILENAME = '/home/03662232677/workspace-neon/PUCOMEX/SS_SNE.ods'
show_ods_sheets(FILENAME)
# Out:
# Spreadsheet contains 1 sheet(s).
# ----------------------------------------
#    Sheet name : 'Incidentes'
# Size of Sheet : (rows=34120, cols=15)

# %%
# Lendo o arquivo ODS com o Pandas
df = read_sheet_ods_as_panda_dataframe(FILENAME)

# %% [markdown]
# ## Inspecionando e trabalhando o DataFrame

# %%
# Mostrando os primeiros registros
df.head()
# Out:
#             ticketid ownergroup description externalsystem  status  \
# 0  2018SS/0000401275  ATCDMGSNE         SNE          EMAIL  CLOSED
# 1  2017SS/0000183234  UNCEDFSNE         SNE          EMAIL  CLOSED
# 2  2017SS/0000183525  CAGSBRSNE         SNE          EMAIL  CLOSED
# 3  2017SS/0000184325  CAGSBRSNE         SNE          EMAIL  CLOSED
# 4  2017SS/0000242075  CAGSBRSNE         SNE          EMAIL  CLOSED
#
#   classificationid serpronivelaten  \
# 0            10252          1NIVEL
# 1            10252          3NIVEL
# 2            10252          2NIVEL
# 3            10252          2NIVEL
# 4            10252          2NIVEL
#
#                                     descricaodemanda          solution  \
# 0  Solicitação de serviço: 2018SS/0000401273 Qual...
# 1  Usuário informa que recebeu umas notificações ...
# 2  Usuário informa que emitiu um boleto que vence...
# 3  Usuário informa que esta tentando cadastrar um...
# 4  Assunto: MULTA PAGA VOLTANDO A CONTAR NO SISTE...  2016SOL/00400157
#
#   classificationid1 description2 relatedreckey internalpriority  \
# 0             10252          SNE                              9
# 1             10252          SNE                              9
# 2             10252          SNE                              9
# 3             10252          SNE                              9
# 4             10252          SNE                              9
#
#                                   solucaoparausuario   NaN
# 0  Prezado Senhor André, O Sistema de Notificação...  None
# 1  Sr. Usuário,\n\nO órgão autuador faz algumas v...  None
# 2  Prezado Angelo,\n\nQual a data de vencimento d...  None
# 3  Prezado Tiago,\nInformamos que o código de seg...  None
# 4  Prezado Jeferson,\n\n\nFavor nos enviar PLACA ...  None

# %%
# Selecionando apenas as colunas desejadas
df = df[['description','ownergroup','descricaodemanda','solution','solucaoparausuario']]

# %%
# Mudando o nome das colunas
df.columns = ['descricao','grupo','descricao_demanda','solucao','solucao_usuario']
df.head()
# Out:
#   descricao      grupo                                  descricao_demanda  \
# 0       SNE  ATCDMGSNE  Solicitação de serviço: 2018SS/0000401273 Qual...
# 1       SNE  UNCEDFSNE  Usuário informa que recebeu umas notificações ...
# 2       SNE  CAGSBRSNE  Usuário informa que emitiu um boleto que vence...
# 3       SNE  CAGSBRSNE  Usuário informa que esta tentando cadastrar um...
# 4       SNE  CAGSBRSNE  Assunto: MULTA PAGA VOLTANDO A CONTAR NO SISTE...
#
#             solucao                                    solucao_usuario
# 0                    Prezado Senhor André, O Sistema de Notificação...
# 1                    Sr. Usuário,\n\nO órgão autuador faz algumas v...
# 2                    Prezado Angelo,\n\nQual a data de vencimento d...
# 3                    Prezado Tiago,\nInformamos que o código de seg...
# 4  2016SOL/00400157  Prezado Jeferson,\n\n\nFavor nos enviar PLACA ...

# %%
# Exibindo estatísticas do pandas
df.describe()
# Out:
#                                          descricao      grupo  \
# count                                        34117      34117
# unique                                          49         23
# top     SNE,INFRAÇÃO / MULTA NÃO DISPONÍVEL NO SNE  ATCDMGSNE
# freq                                          5467      10463
#
#        descricao_demanda             solucao  \
# count              34117               34117
# unique             32139                  89
# top                       2017SOL/0000002593
# freq                 161                5739
#
#                                           solucao_usuario
# count                                               34117
# unique                                              12451
# top     Prezado(a) Sr(a),\n\no cadastro pode ser feito...
# freq                                                 1119

# %%
# Removendo valores vazios em descricao_demanda
df = df.dropna(subset=['descricao_demanda']) 
df = df[df.descricao_demanda != '']
df.describe()
# Out:
#                                          descricao      grupo  \
# count                                        33956      33956
# unique                                          48         23
# top     SNE,INFRAÇÃO / MULTA NÃO DISPONÍVEL NO SNE  ATCDMGSNE
# freq                                          5447      10452
#
#        descricao_demanda             solucao  \
# count              33956               33956
# unique             32138                  88
# top        Adesão ao SNE  2017SOL/0000002593
# freq                 145                5686
#
#                                           solucao_usuario
# count                                               33956
# unique                                              12367
# top     Prezado(a) Sr(a),\n\no cadastro pode ser feito...
# freq                                                 1110

# %%
# removendo colunas indesejadas de grupo
df = df.dropna(subset=['grupo']) 
df = df[df.grupo != '']
grupos = df['grupo'].unique()
print(len(grupos))
grupos
# Out:
# 22
# array(['ATCDMGSNE', 'UNCEDFSNE', 'CAGSBRSNE', 'GSGSSPCENTRODECOMANDO',
#        'ATGSRJ', 'ATGSPEDENATRAN', 'ATGSBRTERC', 'CACDBRLOJASSNE',
#        'GSCDSPLINUX', 'CACDBRSNE', 'GSDEBAAPPSNE', 'GSCDSP',
#        'GSGSDFCENTRODECOMANDO', 'ATGSMG', 'CAGSBRRENAVAM', 'CACDBRRADAR',
#        'CACDBRCNHDIGITAL', 'CAGSBRRENAJUD', 'ATGSRJELETR', 'ATGSBREMAIL',
#        'ATGSPE', 'GSSSDFRADAR'], dtype=object)

# %%
# Removendo quebra de linha da descricao
df['descricao'] = df['descricao'].replace(r'\n','', regex=True)
descricoes = df['descricao'].unique()
print(len(descricoes))
descricoes
# Out:
# 48
# array(['SNE', 'SNE,ACESSO', 'SNE,ACESSO,SISTEMA INDISPONÍVEL-LENTIDÃO',
#        'SNE,ACESSO,SITIO INDISPONÍVEL- LENTIDÃO',
#        'SNE,ACESSO,DÚVIDA - INFORMAÇÃO',
#        'SNE,ACESSO,NAVEGADOR DE INTERNET', 'SNE,APLICAÇÃO',
#        'SNE,APLICAÇÃO,ESCLARECIMENTO', 'SNE,CADASTRO',
#        'SNE,CADASTRO,ACESSO', 'SNE,CADASTRO,DÚVIDA – INFORMAÇÃO',
#        'SNE,CADASTRO,VEÍCULO', 'SNE,SOLICITAÇÃO',
#        'SNE,DÚVIDA - INFORMAÇÃO', 'SNE,SOLICITAÇÃO,DÚVIDA - INFORMAÇÃO',
#        'SNE,SITUAÇÃO NÃO PREVISTA', 'SNE,RECLAMACAO',
#        'SNE,ERRO NA GERAÇÃO DE LINHA DIGITÁVEL/BOLETO DO DETRAN-DF',
#        'SNE,SNE - ERRO NA GERAÇÃO DA LINHA DIGITÁVEL',
#        'SNE,SNE - ERRO NO CADASTRO DO USUÁRIO NO SNE',
#        'SNE,SNE - ERRO NO CADASTRO DE VEÍCULO NO SNE',
#        'SNE,SNE - CADASTRO PESSOA JURÍDICA - CNPJ',
#        'SNE,SNE - CADASTRO DE USUÁRIO PESSOA FÍSICA',
#        'SNE,INFRAÇÃO / MULTA NÃO DISPONÍVEL NO SNE',
#        'SNE,BAIXA DA MULTA NÃO DISPONÍVEL NO SNE',
#        'SNE,SNE - MSG ERRO: OCORREU UM ERRO INESPERADO, RETORNO INVÁLIDO DO SERVIDOR',
#        'SNE,CADASTRO DE VEÍCULO',
#        'SNE,SNE - DÚVIDAS / ORIENTAÇÕES - ÓRGÃO AUTUADOR',
#        'SNE,SNE - LIBERAÇÃO DO BOLETO EM ATÉ 48 HORAS',
#        'SNE,SNE - ERRO ACESSO COM CERTIFICADO DIGITAL',
#        'SNE,SNE - LIBERAÇÃO DO BOLETO EM ATÉ 48 HORAS - AGETOP',
#        'SNE,SNE - ALTERAÇÃO DE E-MAIL NO CADASTRO DO USUÁRIO',
#        'SNE,SNE - LIBERAÇÃO DO BOLETO AM ATÉ 48 HORAS - CAMPINA GRANDE',
#        'SNE,SNE - GERAÇÃO DO BOLETO EM ATÉ 48 HORAS - DNIT',
#        'SNE,SNE - ATENDIMENTO LOJAS',
#        'SNE,SNE - ATENDIMENTO LOJAS,SNE LOJAS – ELOGIO',
#        'SNE,SNE - ATENDIMENTO LOJAS,SNE LOJAS – DESABONA',
#        'SNE,SNE - ATENDIMENTO LOJAS,SNE LOJAS – SUGESTÕES / MELHORIAS',
#        'SNE,SNE - ATENDIMENTO LOJAS,SNE - DÚVIDAS / ORIENTAÇÕES',
#        'SNE,SNE - ATENDIMENTO LOJAS,SNE LOJAS - SE CADASTROU E MULTAS NÃO APARECEM NO SNE',
#        'SNE,SNE - ATENDIMENTO LOJAS,SNE LOJAS - PROBLEMAS NO CADASTRO',
#        'SNE,SNE - ATENDIMENTO LOJAS,SNE LOJAS - ERRO AO CADASTRAR / DESCADASTRAR VEÍCULOS',
#        'SNE,SNE - ATENDIMENTO LOJAS,SNE LOJAS - BOLETOS COM ERRO / NÃO DISPONÍVEL / SEM DESCONTO',
#        'SNE,SNE - ATENDIMENTO LOJAS,SNE LOJAS – LENTIDÃO / INDISPONIBILIDADE',
#        'SNE,SNE - ERRO NO BOLETO BANCÁRIO - PRF',
#        'SNE,SNE - REAL CONDUTOR',
#        'SNE,SNE - PRAZO DO PAGAMENTO COM DESCONTO',
#        'SNE,SNE - ADESÃO AO SNE'], dtype=object)

# %%
# Extraindo o segundo e terceiro termo após a vírgula
import numpy as np
df['sistema'] =  (np.where(df['descricao'].str.contains(','),
                  df['descricao'].str.split(',').str[1],
                  df['descricao']))
df['classificacao'] =  (np.where(df['descricao'].str.contains(','),
                  df['descricao'].str.split(',').str[2],
                  df['descricao']))
# Reorganizando a ordem das colunas
df = df[['sistema','classificacao','grupo', 'descricao_demanda','descricao','solucao','solucao_usuario']]
# Removendo valores nulos das colunas criadas
df = df.dropna(subset=['sistema','classificacao'])
df = df[df.sistema != '']
df = df[df.classificacao != '']
df.describe()
# Out:
#             sistema        classificacao       grupo  \
# count          6291                 6291        6291
# unique            7                   19          20
# top     SOLICITAÇÃO  DÚVIDA - INFORMAÇÃO  ATGSBRTERC
# freq           1789                 2041        2432
#
#                                         descricao_demanda  \
# count                                                6291
# unique                                               5914
# top     Usuário pergunta como pode se CADASTRAR no SIS...
# freq                                                   35
#
#                                   descricao solucao  \
# count                                  6291    6291
# unique                                   20      62
# top     SNE,SOLICITAÇÃO,DÚVIDA - INFORMAÇÃO
# freq                                   1789    1521
#
#                                           solucao_usuario
# count                                                6291
# unique                                               2056
# top     A consulta dos órgãos que fizeram adesão ao SN...
# freq                                                  311

# %%
# Verificando quantos registros existem por sistema
df.groupby('sistema').count()
# Out:
#                                             classificacao  grupo  \
# sistema
# ACESSO                                                420    420
# APLICAÇÃO                                            1438   1438
# CADASTRO                                             1060   1060
# SNE                                                   572    572
# SNE - ATENDIMENTO LOJAS                               915    915
# SNE - MSG ERRO: OCORREU UM ERRO INESPERADO             97     97
# SOLICITAÇÃO                                          1789   1789
#
#                                             descricao_demanda  descricao  \
# sistema
# ACESSO                                                    420        420
# APLICAÇÃO                                                1438       1438
# CADASTRO                                                 1060       1060
# SNE                                                       572        572
# SNE - ATENDIMENTO LOJAS                                   915        915
# SNE - MSG ERRO: OCORREU UM ERRO INESPERADO                 97         97
# SOLICITAÇÃO                                              1789       1789
#
#                                             solucao  solucao_usuario
# sistema
# ACESSO                                          420              420
# APLICAÇÃO                                      1438             1438
# CADASTRO                                       1060             1060
# SNE                                             572              572
# SNE - ATENDIMENTO LOJAS                         915              915
# SNE - MSG ERRO: OCORREU UM ERRO INESPERADO       97               97
# SOLICITAÇÃO                                    1789             1789

# %%
# Escolhendo um sistema para a POC
#SISTEMA_SELECIONADO = 'DUEX - DECLARAÇÃO ÚNICA DE EXPORTAÇÃO'
#df = df.loc[df['sistema'] == SISTEMA_SELECIONADO]
# Mostrando quandos existem por classificacao
df.groupby('classificacao').count()
# Out:
#                                                     sistema  grupo  \
# classificacao
#  RETORNO INVÁLIDO DO SERVIDOR                            97     97
# ACESSO                                                   13     13
# DÚVIDA - INFORMAÇÃO                                    2041   2041
# DÚVIDA – INFORMAÇÃO                                     968    968
# ESCLARECIMENTO                                         1438   1438
# NAVEGADOR DE INTERNET                                    53     53
# SISTEMA INDISPONÍVEL-LENTIDÃO                           100    100
# SITIO INDISPONÍVEL- LENTIDÃO                             15     15
# SNE                                                     572    572
# SNE - DÚVIDAS / ORIENTAÇÕES                             284    284
# SNE LOJAS - BOLETOS COM ERRO / NÃO DISPONÍVEL /...       45     45
# SNE LOJAS - ERRO AO CADASTRAR / DESCADASTRAR VE...       36     36
# SNE LOJAS - PROBLEMAS NO CADASTRO                       143    143
# SNE LOJAS - SE CADASTROU E MULTAS NÃO APARECEM ...      114    114
# SNE LOJAS – DESABONA                                     84     84
# SNE LOJAS – ELOGIO                                      181    181
# SNE LOJAS – LENTIDÃO / INDISPONIBILIDADE                 14     14
# SNE LOJAS – SUGESTÕES / MELHORIAS                        14     14
# VEÍCULO                                                  79     79
#
#                                                     descricao_demanda  \
# classificacao
#  RETORNO INVÁLIDO DO SERVIDOR                                      97
# ACESSO                                                             13
# DÚVIDA - INFORMAÇÃO                                              2041
# DÚVIDA – INFORMAÇÃO                                               968
# ESCLARECIMENTO                                                   1438
# NAVEGADOR DE INTERNET                                              53
# SISTEMA INDISPONÍVEL-LENTIDÃO                                     100
# SITIO INDISPONÍVEL- LENTIDÃO                                       15
# SNE                                                               572
# SNE - DÚVIDAS / ORIENTAÇÕES                                       284
# SNE LOJAS - BOLETOS COM ERRO / NÃO DISPONÍVEL /...                 45
# SNE LOJAS - ERRO AO CADASTRAR / DESCADASTRAR VE...                 36
# SNE LOJAS - PROBLEMAS NO CADASTRO                                 143
# SNE LOJAS - SE CADASTROU E MULTAS NÃO APARECEM ...                114
# SNE LOJAS – DESABONA                                               84
# SNE LOJAS – ELOGIO                                                181
# SNE LOJAS – LENTIDÃO / INDISPONIBILIDADE                           14
# SNE LOJAS – SUGESTÕES / MELHORIAS                                  14
# VEÍCULO                                                            79
#
#                                                     descricao  solucao  \
# classificacao
#  RETORNO INVÁLIDO DO SERVIDOR                              97       97
# ACESSO                                                     13       13
# DÚVIDA - INFORMAÇÃO                                      2041     2041
# DÚVIDA – INFORMAÇÃO                                       968      968
# ESCLARECIMENTO                                           1438     1438
# NAVEGADOR DE INTERNET                                      53       53
# SISTEMA INDISPONÍVEL-LENTIDÃO                             100      100
# SITIO INDISPONÍVEL- LENTIDÃO                               15       15
# SNE                                                       572      572
# SNE - DÚVIDAS / ORIENTAÇÕES                               284      284
# SNE LOJAS - BOLETOS COM ERRO / NÃO DISPONÍVEL /...         45       45
# SNE LOJAS - ERRO AO CADASTRAR / DESCADASTRAR VE...         36       36
# SNE LOJAS - PROBLEMAS NO CADASTRO                         143      143
# SNE LOJAS - SE CADASTROU E MULTAS NÃO APARECEM ...        114      114
# SNE LOJAS – DESABONA                                       84       84
# SNE LOJAS – ELOGIO                                        181      181
# SNE LOJAS – LENTIDÃO / INDISPONIBILIDADE                   14       14
# SNE LOJAS – SUGESTÕES / MELHORIAS                          14       14
# VEÍCULO                                                    79       79
#
#                                                     solucao_usuario
# classificacao
#  RETORNO INVÁLIDO DO SERVIDOR                                    97
# ACESSO                                                           13
# DÚVIDA - INFORMAÇÃO                                            2041
# DÚVIDA – INFORMAÇÃO                                             968
# ESCLARECIMENTO                                                 1438
# NAVEGADOR DE INTERNET                                            53
# SISTEMA INDISPONÍVEL-LENTIDÃO                                   100
# SITIO INDISPONÍVEL- LENTIDÃO                                     15
# SNE                                                             572
# SNE - DÚVIDAS / ORIENTAÇÕES                                     284
# SNE LOJAS - BOLETOS COM ERRO / NÃO DISPONÍVEL /...               45
# SNE LOJAS - ERRO AO CADASTRAR / DESCADASTRAR VE...               36
# SNE LOJAS - PROBLEMAS NO CADASTRO                               143
# SNE LOJAS - SE CADASTROU E MULTAS NÃO APARECEM ...              114
# SNE LOJAS – DESABONA                                             84
# SNE LOJAS – ELOGIO                                              181
# SNE LOJAS – LENTIDÃO / INDISPONIBILIDADE                         14
# SNE LOJAS – SUGESTÕES / MELHORIAS                                14
# VEÍCULO                                                          79

# %%
# Removendo classificaoes com menos que X excemplos
MINIMO_REGISTROS = 50
counts = df['sistema'].value_counts()
df = df[df['sistema'].isin(counts[counts > MINIMO_REGISTROS].index)]
df.groupby('sistema').count()
# Out:
#                                             classificacao  grupo  \
# sistema
# ACESSO                                                420    420
# APLICAÇÃO                                            1438   1438
# CADASTRO                                             1060   1060
# SNE                                                   572    572
# SNE - ATENDIMENTO LOJAS                               915    915
# SNE - MSG ERRO: OCORREU UM ERRO INESPERADO             97     97
# SOLICITAÇÃO                                          1789   1789
#
#                                             descricao_demanda  descricao  \
# sistema
# ACESSO                                                    420        420
# APLICAÇÃO                                                1438       1438
# CADASTRO                                                 1060       1060
# SNE                                                       572        572
# SNE - ATENDIMENTO LOJAS                                   915        915
# SNE - MSG ERRO: OCORREU UM ERRO INESPERADO                 97         97
# SOLICITAÇÃO                                              1789       1789
#
#                                             solucao  solucao_usuario
# sistema
# ACESSO                                          420              420
# APLICAÇÃO                                      1438             1438
# CADASTRO                                       1060             1060
# SNE                                             572              572
# SNE - ATENDIMENTO LOJAS                         915              915
# SNE - MSG ERRO: OCORREU UM ERRO INESPERADO       97               97
# SOLICITAÇÃO                                    1789             1789

# %%
#df2 = df[df.classificacao == 'SITUAÇÃO NÃO PREVISTA']
#df = df[df.classificacao != 'SITUAÇÃO NÃO PREVISTA']
#df.groupby('classificacao').count()

# %%
#df2.groupby('classificacao').count()

# %%
targets = df['sistema'].unique()
print(len(targets))
targets
# Out:
# 7
# array(['SNE', 'ACESSO', 'APLICAÇÃO', 'CADASTRO', 'SOLICITAÇÃO',
#        'SNE - MSG ERRO: OCORREU UM ERRO INESPERADO',
#        'SNE - ATENDIMENTO LOJAS'], dtype=object)

# %%
df.head()
# Out:
#   sistema classificacao      grupo  \
# 0     SNE           SNE  ATCDMGSNE
# 1     SNE           SNE  UNCEDFSNE
# 2     SNE           SNE  CAGSBRSNE
# 3     SNE           SNE  CAGSBRSNE
# 4     SNE           SNE  CAGSBRSNE
#
#                                    descricao_demanda descricao  \
# 0  Solicitação de serviço: 2018SS/0000401273 Qual...       SNE
# 1  Usuário informa que recebeu umas notificações ...       SNE
# 2  Usuário informa que emitiu um boleto que vence...       SNE
# 3  Usuário informa que esta tentando cadastrar um...       SNE
# 4  Assunto: MULTA PAGA VOLTANDO A CONTAR NO SISTE...       SNE
#
#             solucao                                    solucao_usuario
# 0                    Prezado Senhor André, O Sistema de Notificação...
# 1                    Sr. Usuário,\n\nO órgão autuador faz algumas v...
# 2                    Prezado Angelo,\n\nQual a data de vencimento d...
# 3                    Prezado Tiago,\nInformamos que o código de seg...
# 4  2016SOL/00400157  Prezado Jeferson,\n\n\nFavor nos enviar PLACA ...

# %% [markdown]
# ## Preparação dos dados

# %%
# Inicializa o stemmer
stemmer = LancasterStemmer() 
# Stop words para o Português
portuguese_stops = set(stopwords.words('portuguese'))
portuguese_stops.update('é')
# Lista de palavras para remover com regex
include_regex = [r"^[A-Za-zçãàáâéêíóôõúüÂÃÁÀÉÊÍÓÔÕÚÜÇ'º°ª\.]*$",r"^[0-9\-/\\\.]*$"]
#include_regex = [r"^[A-Za-zçãàáâéêíóôõúüÂÃÁÀÉÊÍÓÔÕÚÜÇ'º°ª\.]*$"]
LIMITE_TAMANHO_PALAVRA = 3
# Dicionátio que armazena as pontuações a serem removidas
tbl = {} 
for code in [i for i in range(sys.maxunicode) if unicodedata.category(chr(i)).startswith('P')]:
    tbl[code] = ' '
# Função para remover pontuações das sentenças
def remove_punctuation(text): 
    return text.translate(tbl)
# Função para salvar uma lista em um binário
def save_list_to_file(list_to_save,file_name):
    with open(file_name, 'wb') as f:
        pickle.dump(list_to_save, f)
# Função para realizar o pré-processamento dos conteúdos dos arquivos
def create_doc(txt,target): 
    docs = []
    ngrs = []
    ret = {}
    content = remove_punctuation(txt)
    words = tokenize.word_tokenize(content, language='portuguese')     
    # Remove stopwords
    words = [word for word in words if word.lower() not in portuguese_stops] 
    # Stem de cada palavra, converte para minúsculo 
    words = [stemmer.stem(w.lower()) for w in words] 
    # Remove palavras menores que um limite
    words = [word for word in words if len(word) > LIMITE_TAMANHO_PALAVRA] 
    # Remove regex words
    words_aux = []
    for word in words:
        add = False
        for regex_exp in include_regex:
            if re.compile(regex_exp).match(word):
                add = True
        if add:
            words_aux.append(word)
        #else:
        #    print ('removerndo regex: ',word)
    words = words_aux
    for ngr in ngrams(words,2):
        ngrs.append(ngr)
    ret['ngrams'] = ngrs
    # Busca resultados e adiciona nos docs
    cats = []
    cats.append(target)
    docs.append((ngrs, cats, txt))
    ret['docs'] = docs
    return ret

# %%
count = 0
# Lista de todas as palavras de todos os documentos
all_ngrams = []
# Uma lista de tuplas com as palavras das sentenças e o nome da categoria
docs = [] 
ngr = []
LIMITE = -1
for row_index, row in df.iterrows():
    txt = row['descricao_demanda']
    target = row['sistema']
    count += 1
    ret = create_doc(txt,target)
    docs.extend(ret['docs'])
    all_ngrams.extend(ret['ngrams'])
    if count % 100 == 0:
        print (count,' linhas processadas. Último processado: ',txt)
    if LIMITE != -1 and count == LIMITE:
        break
print (count,' arquivos processados. Último processado: ',txt)
print('\nForam geradas ',len(docs),' combinações e ',len(all_ngrams),' palavras')
print ('\n',len(targets),'Targets: ',targets)
print ('\n',len(docs),'Docs (primeiro): ',docs[:1])
print ('\n',len(all_ngrams),' N-Grams: ',all_ngrams[:100])
# Out:
# 100  linhas processadas. Último processado:  SNE
# 200  linhas processadas. Último processado:  estou tentando acessar o SNE para a Empresa ( Pessoa Jurídica ) mas aparece
# um erro q não localiza a pagina. Este Software esta disponível para empresa
# ou somente para pessoa física?
# 300  linhas processadas. Último processado:  REF. AUTO NOTIFICAÇÃO E AUTUAÇÃO Nº 0042792538 E Nº 0042792617 PELA PRF
# INFORMA PARA PAGTO SEM RECORRER E 40% COMO FAÇO NÃO ESTAMOS CONSEGUINDO
# IMPRIMIR BOLETO, SERPRO ESTA FORA AR
# 400  linhas processadas. Último processado:  Usuário deseja informações de como cadastrar pessoa Jurídica no SNE
# 500  linhas processadas. Último processado:  Usuário deseja informações sobre cadastro de CNPJ no sne.
# 600  linhas processadas. Último processado:  Usuário informa que baixou o app e ao clicar no link para confirmar o
# cadastro o sistema informa que o site não é seguro.
# 700  linhas processadas. Último processado:  Boa tarde, estou com problemas para emitir o boleto para pagamento com o
# desconto de 40% através do aplicativo SNE. Ao reconhecer a infração e
# aceitar os termos e condições aparece a seguinte mensagem: "erro ao acionar
# o órgão autuador". Gostaria de saber como proceder. OBS: Encaminho anexada
# à solicitação o print de tela em que ocorre o erro. Obrigada.
# 800  linhas processadas. Último processado:  Usuário solicita informações sobre a multa que recebeu e realizou o
# pagamento com código de barras.
# 900  linhas processadas. Último processado:  Usuário solicita informação sobre a SNE, pois não consta no sistema a multa
# atuada.
# 1000  linhas processadas. Último processado:  Informação sobre SNE.
# 1100  linhas processadas. Último processado:  Boa tarde, recebi uma notificação e a informação de que entrando no site eu
# conseguiria tirar o valor da multa com 40% de desconto, mas eu não consegui
# tirar o boleto para pagar, eu só consigo tirar depois que passa do prazo
# para defesa? No aguardo, grato, att, Jonatã SIlveira
# 1200  linhas processadas. Último processado:  Usuário solicita de informações referentes ao SNE.
# 1300  linhas processadas. Último processado:  Boa noite. Fiz o download do aplicativo e cadastrei meus veículos, porém
# não aparecem as multas no ícone de infrações.. Todas infrações são validas
# para o desconto? As infrações anteriores ao download do aplicativo também?
# Obrigado.
# 1400  linhas processadas. Último processado:  Usuária informa que ao tentar gerar desconto o sistema apresenta o erro
# abaixo:
#
# Erro:  Caro cidadão o sistema DNIT está sendo atualizado, para geração  de
# boleto para pagamento está suspensa temporariamente. Assim que a
# atualização for concluída o desconto será concedido sem prejuízo.
# 1500  linhas processadas. Último processado:  Usuário informa que recebeu uma multa do DNIT e não consta notificação no
# aplicativo SNE.
# 1600  linhas processadas. Último processado:  Usuária informa que tem dificuldades para pagar multa diretamente do
# programa.
# 1700  linhas processadas. Último processado:  Usuário solicita informações sobre pagamento de multa através do aplicativo
# SNE.
# 1800  linhas processadas. Último processado:  Usuário solicita visualizar uma multa, pois no aplicativo não consta a
# multa e no detran consta.
# 1900  linhas processadas. Último processado:  Usuária relata que efetuou o pagamento das multas pelo SNE, mas ainda
# constam na base.
# 2000  linhas processadas. Último processado:  Usuária informa verificou pela manhã app sne apresentava as notificações
# Detran DF ao verificar pela tarde não esta apresentado notificações
# anteriores.
# 2100  linhas processadas. Último processado:  Não recebi o boleto com desconto e agora o prazo da multa original venceu e
# vou pagar juros em cima dk valor cheio. E agora?
# 2200  linhas processadas. Último processado:  Não possuo carteira de habilitação, meu filho quem usa o carro. Portanto no
# meu cadastro opto pela opção sem carteira de habilitação. Entao tenho que
# preencher com renavam e o código de segurança do renavam, certo? O código a
# que me refiro é do documento do veículo, o qual solicitam também o código
# de segurança que fica na parte superior direita como o próprio aplicativo
# já indica. ao colocar o código de segurança do renavam recebo essa
# mensagem: Atenção! Não foi possível validar os dados: Os dados informados
# não constam no cadastro pode me ajudar?
# 2300  linhas processadas. Último processado:   Usuária informa ao acessa link para validação seu cadastro sne, apresenta
# mensagem este site não é seguro.
# 2400  linhas processadas. Último processado:  Usuário solicita informações para cadastrar-se no SNE.
# 2500  linhas processadas. Último processado:   Usuário informa ao logar app SNE apresenta mensagem usuário invalido .
# 2600  linhas processadas. Último processado:  Usuário solicita informações sobre código de segurança da CNH
# 2700  linhas processadas. Último processado:  Ao tentar me cadastrar no portal do Denatran (SNE), consta que meu CPF já
# está em uso, porém não efetuei nenhum cadastro e quando vou na área
# "esqueci a minha senha", ele envia para um email desconhecido. Gostaria de
# efetuar o cancelamento do cadastro no qual está sendo usado meu CPF ou
# modificar os dados para o dono real.
# 2800  linhas processadas. Último processado:  Não consigo recuperar minha senha
# 2900  linhas processadas. Último processado:  Tenho cadastro e não consigo acessar o portal.
# 3000  linhas processadas. Último processado:  esqueci a senha mais não esta manda a senha no email
# 3100  linhas processadas. Último processado:  bom dia, errei no link, era pra gerar documento para indicacao de condutor
# e coloquei em gerar boleto, como faco para corrigir.
# 3200  linhas processadas. Último processado:  Não estou conseguido cadastrar meu veículo no site e nem no aplicativo da
# SNE pede o número do RENAVAM e o cód de segurança mais não tem já olhei na
# opção que destaca onde é que fica e não aparece, como posso proceder?
# 3300  linhas processadas. Último processado:  Gostaria de saber como tenho acesso a imagem da minha falha na rodovia onde
# recebi uma multa, cuja número da notificação de autuação é 0051722788.
# 3400  linhas processadas. Último processado:  Fiz o cadastro no SNE e cadastrei o meu veículo.... Verifiquei que existiam
# duas multas e efetuei o pagamento de uma delas... a outra não gerei o
# boleto e nem dei seguimento nisso.... mas quando quando fui consultar
# novamente o status desta multa estava vencida... no sistema não constava
# data de vencimento e não recebi nenhuma informação sobre isso... agora não
# tenho condições de pagar essa multa no momento. Deve ter ocorrido algum
# erro no sistema de vocês pois não tem a opção de desconto e estão cobrando
# multa por atraso, sendo que não optei por pagá-la em momento algum. Por
# favor retornem o status anterior desta multa para que em data oportuna
# possa ter o direito de pagar com os mesmos descontos da outra multa que fiz
# o pagamento. Obrigado.
# 3500  linhas processadas. Último processado:  Informações sobre multa.
# 3600  linhas processadas. Último processado:  Usuário do SNE informa mensagem de erro abaixo:
#
# Mensagem: Erro ao assinar o orgão atuador .
#
# Multa da PM
#
# 3700  linhas processadas. Último processado:  Usuário informa que possui uma infração / multa aplicada pela prf(polícia
# rodoviária federal), que antes era visualizada permitindo o desconto de 40%
# e agora não mais está aparecendo. muitas vezes exibindo a mensagem: “não há
# notificações, aguardando o renainf”.
# 3800  linhas processadas. Último processado:  Usuário deseja informações sobre por que multa não foi apresenta no
# aplicativo sne
# 3900  linhas processadas. Último processado:  Usuário solicita orientação notificação PRF.
# 4000  linhas processadas. Último processado:  Tenho uma multa da PRF para pagar, mas pelo aplicativo SNE não aparece
# nada. Não vou conseguir os 40% de desconto?
# 4100  linhas processadas. Último processado:  Usuária solicita informações para saber o órgão atuador de sua multa.
# 4200  linhas processadas. Último processado:  pagamento de multa com desconto de 40% NÃO APRESENTAREI DEFESA NEM
# RECURSO,RECONHECENDO O COMETIMENTO DA INFRAÇÃO,NOTIFICAÇÃO DA PENALIDADE
# 40042320
# 4300  linhas processadas. Último processado:  Usuário informa que foi autuado pela Polícia Rodoviária Federal, fez o
# cadastro no aplicativo SNE e não apareceu a multa para desconto.
# 4400  linhas processadas. Último processado:  Usuária solicita orientação notificado PRF.
# 4500  linhas processadas. Último processado:  Usuário solicita orientações para saber como proceder a respeito do
# aplicativo do SNE.
# 4600  linhas processadas. Último processado:   Usuária solicita informações para efetuar o pagamento da multa com 40% de
# desconto
# 4700  linhas processadas. Último processado:  Usuário gerou boleto com desconto, porém perdeu o prazo de pagamento. O
# mesmo solicita informações sobre como conseguiu segunda via do boleto com
# desconto
#
# Placa: jgm7222
# Orgão : detran- df
# data da autuação:--
# auto de infração st00770344
#  renavam:  00948498803
#
# 4800  linhas processadas. Último processado:   Usuário relata que os descontos de 40% na multa efetuada pelo DETRAN- SC
# não está apresentando no SNE
# 4900  linhas processadas. Último processado:  GOSTARIA DE ADERIR PARA OBTER O DESCONTO.
# 5000  linhas processadas. Último processado:  Como descadastrar um veículo... OIE 1204.
# 5100  linhas processadas. Último processado:  Não consigo gerar o boleto da infração nem recebi no meu e-mail. Número do
# Auto de Infração CM00779568
# 5200  linhas processadas. Último processado:  Usuária deseja parcelar multas no cartão de credito.
# 5300  linhas processadas. Último processado:  Bom dia, já solicitei a mais de um mês ajudar para resolver meu problema e
# até agora sem resposta! é o seguinte fiz o cadastro no SNE mas nem pelo
# aplicativo nem pelo site consigo o desconto de 40% e nem o boleto para
# pagamento, aparece a seguinte frase "Requisição Inválida" aguardo resposta
# com a solução?
# 5400  linhas processadas. Último processado:  Olá, Um usuário escreveu uma nova resenha sobre seu app. Você pode
# responder a ela no Google Play Developer Console.
#
# Nova resenha em 30 de ago de 2018, 17:58 (GMT) ★★★★★ Funciona muito bem.
# Responder
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOHqP3SnOhMRZDpztq9Ur5syp6F5_ovyDcfPW4DvAUdbFn6jVEgenH41o46iEZRj4F0fistDnx6TocdO3LA>
# Atenciosamente, *equipe do Google Play*
# <https://support.google.com/googleplay/android-developer/answer/138230>.
# <https://support.google.com/googleplay/android-developer/answer/113417>.
# <https://play.google.com/apps/publish?account=7590937500426216625#EmailPrefsPlace>
# .
#
# RESPONDER:
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOHqP3SnOhMRZDpztq9Ur5syp6F5_ovyDcfPW4DvAUdbFn6jVEgenH41o46iEZRj4F0fistDnx6TocdO3LA>
#
# 5500  linhas processadas. Último processado:  Olá, Um usuário escreveu uma nova resenha sobre seu app. Você pode
# responder a ela no Play Console.
#
# Nova resenha em 14 de jan de 2019, 19:11 (GMT) ★★★★ Muito bom ... agiliza
# demais . recomendo Responder
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOGIKaDFs9bJ8c5msOl2ns1Ph2VdY-zVCOAV4NHvXmkntc1M47Bc6U8ACfbdzuT3PpSkATwZ9X8MhEj0cTA>
# Atenciosamente, *equipe do Google Play*
# <https://support.google.com/googleplay/android-developer/answer/138230>.
# <https://support.google.com/googleplay/android-developer/answer/113417>.
# <https://play.google.com/apps/publish?account=7590937500426216625#EmailPrefsPlace>
# .
#
# RESPONDER:
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOGIKaDFs9bJ8c5msOl2ns1Ph2VdY-zVCOAV4NHvXmkntc1M47Bc6U8ACfbdzuT3PpSkATwZ9X8MhEj0cTA>
#
# 5600  linhas processadas. Último processado:  Olá, Um usuário escreveu uma nova resenha sobre seu app. Você pode
# responder a ela no Google Play Developer Console.
#
# Nova resenha em 17 de nov de 2018, 15:28 (GMT) ★ Porque na minha cidade foi
# suspenso a adesão ? Responder
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOFg5ktqG03HEyjVnveVoN0PBZmOcIx7yuuElkHTgPRyzken53MbBRcTZTsVxCMmOTbYSgI8PtAEch_fHeI>
# Atenciosamente, *equipe do Google Play*
# <https://support.google.com/googleplay/android-developer/answer/138230>.
# <https://support.google.com/googleplay/android-developer/answer/113417>.
# <https://play.google.com/apps/publish?account=7590937500426216625#EmailPrefsPlace>
# .
#
# RESPONDER:
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOFg5ktqG03HEyjVnveVoN0PBZmOcIx7yuuElkHTgPRyzken53MbBRcTZTsVxCMmOTbYSgI8PtAEch_fHeI>
#
# 5700  linhas processadas. Último processado:  Olá, Um usuário escreveu uma nova resenha sobre seu app. Você pode
# responder a ela no Google Play Developer Console.
#
# Nova resenha em 2 de out de 2018, 18:50 (GMT) ★★★ Antes apareciam as multas
# que ainda estavam em aberto para pagar. Agora nao aparecem mais nem as que
# eu paguei e nem as que estão prestes a vencer! Como soluciono isso? Aparece
# apenas a msg. ''Você nao possui nenhuma notificação recente" Responder
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOE0N7bElZfnnimdCS6HpOLOCKrpBEa8sWJLJG3KTEzS544C905salCi9vdZVYKfsE1BGNiheEdKF7SfXD4>
# Atenciosamente, *equipe do Google Play*
# <https://support.google.com/googleplay/android-developer/answer/138230>.
# <https://support.google.com/googleplay/android-developer/answer/113417>.
# <https://play.google.com/apps/publish?account=7590937500426216625#EmailPrefsPlace>
# .
#
# RESPONDER:
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOE0N7bElZfnnimdCS6HpOLOCKrpBEa8sWJLJG3KTEzS544C905salCi9vdZVYKfsE1BGNiheEdKF7SfXD4>
#
# 5800  linhas processadas. Último processado:  Olá, Um usuário escreveu uma nova resenha sobre seu app. Você pode
# responder a ela no Google Play Developer Console.
#
# Nova resenha em 20 de dez de 2018, 20:02 (GMT) ★★★ não consegui o desconto
# de 40% a aplicativo não gerava o desconto,acbou que não paguei com desconto
# porque a data de pagamento expirou. Responder
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOElcuuqosLQJooK0hc7dOB8xgY8jtJTfXLdn6BiyHuqtYAbubBs-hampR-vQ6QeVPObmL2Y-TyZWHy4Swk>
# Atenciosamente, *equipe do Google Play*
# <https://support.google.com/googleplay/android-developer/answer/138230>.
# <https://support.google.com/googleplay/android-developer/answer/113417>.
# <https://play.google.com/apps/publish?account=7590937500426216625#EmailPrefsPlace>
# .
#
# RESPONDER:
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOElcuuqosLQJooK0hc7dOB8xgY8jtJTfXLdn6BiyHuqtYAbubBs-hampR-vQ6QeVPObmL2Y-TyZWHy4Swk>
#
# 5900  linhas processadas. Último processado:  Olá, Um usuário escreveu uma nova resenha sobre seu app. Você pode
# responder a ela no Play Console.
#
# Nova resenha em 8 de fev de 2019, 13:44 (GMT) ★ Não dá baixa na multa app
# não funciona pois paguei o boleto gerado a multa apos cinco dias ainda
# consta no sistema. Alerta app não confiável! Responder
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOGSxklCjSJieQmQR3ZGcNYtOZ0_Elgy6sock5PL0gpd5ZbYhT6PuAEACpe_TI-imccgbLmwYTbv8syzD4k>
# Atenciosamente, *equipe do Google Play*
# <https://support.google.com/googleplay/android-developer/answer/138230>.
# <https://support.google.com/googleplay/android-developer/answer/113417>.
# <https://play.google.com/apps/publish?account=7590937500426216625#EmailPrefsPlace>
# .
#
# RESPONDER:
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOGSxklCjSJieQmQR3ZGcNYtOZ0_Elgy6sock5PL0gpd5ZbYhT6PuAEACpe_TI-imccgbLmwYTbv8syzD4k>
#
# 6000  linhas processadas. Último processado:  Olá, Um usuário escreveu uma nova resenha sobre seu app. Você pode
# responder a ela no Google Play Developer Console.
#
# Nova resenha em 17 de out de 2018, 17:54 (GMT) ★★★ Boa tarde Senhores.
# olhei no site DETRANNET e tenho uma autuação do DER/MG, mas não aparece no
# aplicativo. Queria saber o pq? Responder
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOEnWDwhBqA7KlkWFgysBb1u7ikvE8UKuOdLkfVaNgO6iKvpbMKW5HIY8BpshHCukUla4Q8sebGpC6F5Mv8>
# Atenciosamente, *equipe do Google Play*
# <https://support.google.com/googleplay/android-developer/answer/138230>.
# <https://support.google.com/googleplay/android-developer/answer/113417>.
# <https://play.google.com/apps/publish?account=7590937500426216625#EmailPrefsPlace>
# .
#
# RESPONDER:
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOEnWDwhBqA7KlkWFgysBb1u7ikvE8UKuOdLkfVaNgO6iKvpbMKW5HIY8BpshHCukUla4Q8sebGpC6F5Mv8>
#
# 6100  linhas processadas. Último processado:  Olá, Um usuário escreveu uma nova resenha sobre seu app. Você pode
# responder a ela no Google Play Developer Console.
#
# Nova resenha em 13 de set de 2018, 22:38 (GMT) ★ O código é somente para
# aqueles que tem o Código de segurança (Ou seja, carros acima de 2006)
# Responder
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOFYqcO8qEcdDlop6NfRgS1gQYvO2Y62mn9nLa_doUlAjYP-MJ4rjtH-vrsrNP25i980nqXoKGp1LYDtiCU>
# Atenciosamente, *equipe do Google Play*
# <https://support.google.com/googleplay/android-developer/answer/138230>.
# <https://support.google.com/googleplay/android-developer/answer/113417>.
# <https://play.google.com/apps/publish?account=7590937500426216625#EmailPrefsPlace>
# .
#
# RESPONDER:
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOFYqcO8qEcdDlop6NfRgS1gQYvO2Y62mn9nLa_doUlAjYP-MJ4rjtH-vrsrNP25i980nqXoKGp1LYDtiCU>
# 6200  linhas processadas. Último processado:  Não aparece meu veículo....afirma que não tem carro no meu CPF no renavam.
# Ou seja, não deve pra nada
# https://appstoreconnect.apple.com/WebObjects/iTunesConnect.woa/ra/ng/app/1170007091/activity/ios/ratingsResponses
#
# 6291  arquivos processados. Último processado:  Olá, Um usuário escreveu uma nova resenha sobre seu app. Você pode
# responder a ela no Play Console.
#
# Nova resenha em 17 de fev de 2019, 13:48 (GMT) ★ o app falha toda vez que
# tento entrar Responder
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOEInmekYGUYopFzNbqfQmfItb64IUgn4BCuOeJFtETFxe0M4G6-B1aWzaaWiPtkl8MXxNztO_xGqxipqJA>
# Atenciosamente, *equipe do Google Play*
# <https://support.google.com/googleplay/android-developer/answer/138230>.
# <https://support.google.com/googleplay/android-developer/answer/113417>.
# <https://play.google.com/apps/publish?account=7590937500426216625#EmailPrefsPlace>
# .
#
# RESPONDER:
# <https://play.google.com/apps/publish?account=7590937500426216625#ReviewDetailsPlace:p=br.gov.serpro.denatran.sne&reviewid=gp:AOqpTOEInmekYGUYopFzNbqfQmfItb64IUgn4BCuOeJFtETFxe0M4G6-B1aWzaaWiPtkl8MXxNztO_xGqxipqJA>
#
#
# Foram geradas  6291  combinações e  126507  palavras
#
#  7 Targets:  ['SNE' 'ACESSO' 'APLICAÇÃO' 'CADASTRO' 'SOLICITAÇÃO'
#  'SNE - MSG ERRO: OCORREU UM ERRO INESPERADO' 'SNE - ATENDIMENTO LOJAS']
#
#  6291 Docs (primeiro):  [([('solicitação', 'serviço'), ('serviço', '0000401273'), ('0000401273', 'procedimento'), ('procedimento', 'agor')], ['SNE'], 'Solicitação de serviço: 2018SS/0000401273 Qual o procedimento agora?')]
#
#  126507  N-Grams:  [('solicitação', 'serviço'), ('serviço', '0000401273'), ('0000401273', 'procedimento'), ('procedimento', 'agor'), ('usuário', 'inform'), ('inform', 'recebeu'), ('recebeu', 'notificaçõ'), ('notificaçõ', 'aplicativo'), ('aplicativo', 'veículo'), ('veículo', 'clic'), ('clic', 'opção'), ('opção', 'aparec'), ('aparec', 'apena'), ('apena', 'sendo'), ('sendo', 'entrau'), ('entrau', 'nenh'), ('nenh', 'recurso'), ('recurso', 'processo'), ('processo', 'administrativo'), ('administrativo', 'junto'), ('junto', 'plac'), ('plac', 'órgão'), ('órgão', 'autuad'), ('autuad', 'notificação'), ('notificação', 'autuação'), ('autuação', '2017'), ('usuário', 'inform'), ('inform', 'emitiu'), ('emitiu', 'boleto'), ('boleto', 'venceu'), ('venceu', 'prazo'), ('prazo', 'acabou'), ('acabou', 'vendendo'), ('vendendo', 'carro'), ('carro', 'mult'), ('mult', 'sumiu'), ('sumiu', 'tanto'), ('tanto', 'pesso'), ('pesso', 'comprou'), ('comprou', 'carro'), ('carro', 'solicit'), ('solicit', 'orientaçõ'), ('orientaçõ', 'actuação'), ('actuação', 'políc'), ('políc', 'rodoviár'), ('rodoviár', 'plac'), ('plac', 'órgão'), ('órgão', 'autuad'), ('autuad', 'polic'), ('polic', 'rodoviár'), ('rodoviár', 'notificação'), ('notificação', 'autuação'), ('autuação', '2016'), ('usuário', 'inform'), ('inform', 'tentando'), ('tentando', 'cadastr'), ('cadastr', 'veiculo'), ('veiculo', 'inserir'), ('inserir', 'código'), ('código', 'apresent'), ('apresent', 'seguint'), ('seguint', 'mensagem'), ('mensagem', 'código'), ('código', 'seguranç'), ('seguranç', 'invalido'), ('invalido', 'sendo'), ('sendo', 'código'), ('código', 'digito'), ('assunto', 'mult'), ('mult', 'voltando'), ('voltando', 'cont'), ('cont', 'sistem'), ('sistem', 'jeferson'), ('jeferson', 'matia'), ('matia', 'fisommatia'), ('fisommatia', 'gmail'), ('gmail', '2017'), ('2017', 'destinatário'), ('destinatário', 'serpro'), ('serpro', 'serpro'), ('serpro', 'anexo'), ('anexo', 'comprov'), ('comprov', 'pagamento'), ('pagamento', 'mult'), ('mult', 'docx'), ('docx', 'sagrificio'), ('sagrificio', 'consegu'), ('consegu', 'mult'), ('mult', 'gerado'), ('gerado', 'aplicativo'), ('aplicativo', 'unico'), ('unico', 'banco'), ('banco', 'aceitou'), ('aceitou', 'receb'), ('receb', 'mult'), ('mult', 'banco'), ('banco', 'brasil'), ('brasil', 'pagamento'), ('pagamento', 'feito'), ('feito', 'caix')]

# %%
# Store data (serialize)
save_list_to_file(targets,'targets.pickle')
save_list_to_file(all_ngrams,'all_ngrams.pickle')
save_list_to_file(docs,'docs.pickle')
print ('Arquivos salvos com sucesso!')
# Out:
# Arquivos salvos com sucesso!

# %% [markdown]
# FIM
